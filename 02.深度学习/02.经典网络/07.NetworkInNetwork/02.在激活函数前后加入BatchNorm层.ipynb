# %% [markdown]
# 在激活函数前后加入BatchNorm层
# ===

# %%
import os
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torch.utils.data import Subset

from torchvision import datasets
from torchvision import transforms

import matplotlib.pyplot as plt
from PIL import Image

if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True

# %% [markdown]
# # 1.全局设置

# %%
RANDOM_SEED = 1
LEARNING_RATE = 0.0005
BATCH_SIZE = 256
NUM_EPOCHS = 100

# Architecture
NUM_CLASSES = 10

# Other
DEVICE = "cuda:0"
GRAYSCALE = False

# %% [markdown]
# # 2.导入数据

# %%
train_indices = torch.arange(0, 49000)
valid_indices = torch.arange(49000, 50000)


train_and_valid = datasets.CIFAR10(root='/input/', 
                                   train=True, 
                                   transform=transforms.ToTensor(),
                                   download=True)

train_dataset = Subset(train_and_valid, train_indices)
valid_dataset = Subset(train_and_valid, valid_indices)


test_dataset = datasets.CIFAR10(root='/input/', 
                                train=False, 
                                transform=transforms.ToTensor())


#####################################################
### Data Loaders
#####################################################

train_loader = DataLoader(dataset=train_dataset, 
                          batch_size=BATCH_SIZE,
                          num_workers=8,
                          shuffle=True)

valid_loader = DataLoader(dataset=valid_dataset, 
                          batch_size=BATCH_SIZE,
                          num_workers=8,
                          shuffle=False)

test_loader = DataLoader(dataset=test_dataset, 
                         batch_size=BATCH_SIZE,
                         num_workers=8,
                         shuffle=False)
# Out:
# Files already downloaded and verified

# %% [markdown]
# # 3.模型与训练

# %% [markdown]
# ## 3.1.不加入BatchNorm层

# %%
class NiN(nn.Module):
    def __init__(self, num_classes):
        super(NiN, self).__init__()
        self.num_classes = num_classes
        self.classifier = nn.Sequential(
                nn.Conv2d(3, 192, kernel_size=5, stride=1, padding=2),
                nn.ReLU(inplace=True),
                nn.Conv2d(192, 160, kernel_size=1, stride=1, padding=0),
                nn.ReLU(inplace=True),
                nn.Conv2d(160,  96, kernel_size=1, stride=1, padding=0),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
                nn.Dropout(0.5),

                nn.Conv2d(96, 192, kernel_size=5, stride=1, padding=2),
                nn.ReLU(inplace=True),
                nn.Conv2d(192, 192, kernel_size=1, stride=1, padding=0),
                nn.ReLU(inplace=True),
                nn.Conv2d(192, 192, kernel_size=1, stride=1, padding=0),
                nn.ReLU(inplace=True),
                nn.AvgPool2d(kernel_size=3, stride=2, padding=1),
                nn.Dropout(0.5),

                nn.Conv2d(192, 192, kernel_size=3, stride=1, padding=1),
                nn.ReLU(inplace=True),
                nn.Conv2d(192, 192, kernel_size=1, stride=1, padding=0),
                nn.ReLU(inplace=True),
                nn.Conv2d(192,  10, kernel_size=1, stride=1, padding=0),
                nn.ReLU(inplace=True),
                nn.AvgPool2d(kernel_size=8, stride=1, padding=0),

                )

    def forward(self, x):
        x = self.classifier(x)
        logits = x.view(x.size(0), self.num_classes)
        probas = torch.softmax(logits, dim=1)
        return logits, probas

# %%
torch.manual_seed(RANDOM_SEED)

model = NiN(NUM_CLASSES)
model.to(DEVICE)

optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %%
def compute_accuracy(model, data_loader, device):
    correct_pred, num_examples = 0, 0
    for i, (features, targets) in enumerate(data_loader):
            
        features = features.to(device)
        targets = targets.to(device)

        logits, probas = model(features)
        _, predicted_labels = torch.max(probas, 1)
        num_examples += targets.size(0)
        correct_pred += (predicted_labels == targets).sum()
    return correct_pred.float()/num_examples * 100
    

start_time = time.time()
for epoch in range(NUM_EPOCHS):
    
    model.train()
    
    for batch_idx, (features, targets) in enumerate(train_loader):
    
        ### PREPARE MINIBATCH
        features = features.to(DEVICE)
        targets = targets.to(DEVICE)
            
        ### FORWARD AND BACK PROP
        logits, probas = model(features)
        cost = F.cross_entropy(logits, targets)
        optimizer.zero_grad()
        
        cost.backward()
        
        ### UPDATE MODEL PARAMETERS
        optimizer.step()
        
        ### LOGGING
        if not batch_idx % 120:
            print (f'Epoch: {epoch+1:03d}/{NUM_EPOCHS:03d} | '
                   f'Batch {batch_idx:03d}/{len(train_loader):03d} |' 
                   f' Cost: {cost:.4f}')

    # no need to build the computation graph for backprop when computing accuracy
    with torch.set_grad_enabled(False):
        train_acc = compute_accuracy(model, train_loader, device=DEVICE)
        valid_acc = compute_accuracy(model, valid_loader, device=DEVICE)
        print(f'Epoch: {epoch+1:03d}/{NUM_EPOCHS:03d} Train Acc.: {train_acc:.2f}%'
              f' | Validation Acc.: {valid_acc:.2f}%')
        
    elapsed = (time.time() - start_time)/60
    print(f'Time elapsed: {elapsed:.2f} min')
  
elapsed = (time.time() - start_time)/60
print(f'Total Training Time: {elapsed:.2f} min')
# Out:
# Epoch: 001/100 | Batch 000/192 | Cost: 2.3043
# Epoch: 001/100 | Batch 120/192 | Cost: 2.0062
# Epoch: 001/100 Train Acc.: 26.97% | Validation Acc.: 28.60%
# Time elapsed: 0.35 min
# Epoch: 002/100 | Batch 000/192 | Cost: 1.8996
# Epoch: 002/100 | Batch 120/192 | Cost: 1.8640
# Epoch: 002/100 Train Acc.: 33.31% | Validation Acc.: 32.80%
# Time elapsed: 0.69 min
# Epoch: 003/100 | Batch 000/192 | Cost: 1.7248
# Epoch: 003/100 | Batch 120/192 | Cost: 1.7386
# Epoch: 003/100 Train Acc.: 36.32% | Validation Acc.: 36.00%
# Time elapsed: 1.02 min
# Epoch: 004/100 | Batch 000/192 | Cost: 1.7034
# Epoch: 004/100 | Batch 120/192 | Cost: 1.5707
# Epoch: 004/100 Train Acc.: 40.21% | Validation Acc.: 42.70%
# Time elapsed: 1.36 min
# Epoch: 005/100 | Batch 000/192 | Cost: 1.6372
# Epoch: 005/100 | Batch 120/192 | Cost: 1.6354
# Epoch: 005/100 Train Acc.: 43.71% | Validation Acc.: 45.90%
# Time elapsed: 1.70 min
# Epoch: 006/100 | Batch 000/192 | Cost: 1.6369
# Epoch: 006/100 | Batch 120/192 | Cost: 1.4114
# Epoch: 006/100 Train Acc.: 47.08% | Validation Acc.: 48.00%
# Time elapsed: 2.04 min
# Epoch: 007/100 | Batch 000/192 | Cost: 1.5766
# Epoch: 007/100 | Batch 120/192 | Cost: 1.5053
# Epoch: 007/100 Train Acc.: 49.25% | Validation Acc.: 50.80%
# Time elapsed: 2.37 min
# Epoch: 008/100 | Batch 000/192 | Cost: 1.4324
# Epoch: 008/100 | Batch 120/192 | Cost: 1.3724
# Epoch: 008/100 Train Acc.: 51.86% | Validation Acc.: 51.50%
# Time elapsed: 2.71 min
# Epoch: 009/100 | Batch 000/192 | Cost: 1.2979
# Epoch: 009/100 | Batch 120/192 | Cost: 1.3761
# Epoch: 009/100 Train Acc.: 54.57% | Validation Acc.: 54.20%
# Time elapsed: 3.05 min
# Epoch: 010/100 | Batch 000/192 | Cost: 1.2372
# Epoch: 010/100 | Batch 120/192 | Cost: 1.2880
# Epoch: 010/100 Train Acc.: 54.51% | Validation Acc.: 54.50%
# Time elapsed: 3.38 min
# Epoch: 011/100 | Batch 000/192 | Cost: 1.2764
# Epoch: 011/100 | Batch 120/192 | Cost: 1.2328
# Epoch: 011/100 Train Acc.: 56.15% | Validation Acc.: 57.40%
# Time elapsed: 3.72 min
# Epoch: 012/100 | Batch 000/192 | Cost: 1.1678
# Epoch: 012/100 | Batch 120/192 | Cost: 1.3974
# Epoch: 012/100 Train Acc.: 56.59% | Validation Acc.: 56.30%
# Time elapsed: 4.06 min
# Epoch: 013/100 | Batch 000/192 | Cost: 1.2192
# Epoch: 013/100 | Batch 120/192 | Cost: 1.3187
# Epoch: 013/100 Train Acc.: 58.05% | Validation Acc.: 56.90%
# Time elapsed: 4.39 min
# Epoch: 014/100 | Batch 000/192 | Cost: 1.1775
# Epoch: 014/100 | Batch 120/192 | Cost: 1.2567
# Epoch: 014/100 Train Acc.: 59.74% | Validation Acc.: 59.40%
# Time elapsed: 4.73 min
# Epoch: 015/100 | Batch 000/192 | Cost: 1.1685
# Epoch: 015/100 | Batch 120/192 | Cost: 1.1657
# Epoch: 015/100 Train Acc.: 61.36% | Validation Acc.: 59.70%
# Time elapsed: 5.07 min
# Epoch: 016/100 | Batch 000/192 | Cost: 1.0738
# Epoch: 016/100 | Batch 120/192 | Cost: 1.1945
# Epoch: 016/100 Train Acc.: 60.92% | Validation Acc.: 60.30%
# Time elapsed: 5.41 min
# Epoch: 017/100 | Batch 000/192 | Cost: 1.1704
# Epoch: 017/100 | Batch 120/192 | Cost: 1.1047
# Epoch: 017/100 Train Acc.: 62.12% | Validation Acc.: 62.40%
# Time elapsed: 5.74 min
# Epoch: 018/100 | Batch 000/192 | Cost: 1.1363
# Epoch: 018/100 | Batch 120/192 | Cost: 1.1294
# Epoch: 018/100 Train Acc.: 63.44% | Validation Acc.: 60.50%
# Time elapsed: 6.08 min
# Epoch: 019/100 | Batch 000/192 | Cost: 1.2039
# Epoch: 019/100 | Batch 120/192 | Cost: 1.1191
# Epoch: 019/100 Train Acc.: 64.39% | Validation Acc.: 62.50%
# Time elapsed: 6.42 min
# Epoch: 020/100 | Batch 000/192 | Cost: 1.0080
# Epoch: 020/100 | Batch 120/192 | Cost: 0.9763
# Epoch: 020/100 Train Acc.: 65.41% | Validation Acc.: 63.50%
# Time elapsed: 6.75 min
# Epoch: 021/100 | Batch 000/192 | Cost: 1.0146
# Epoch: 021/100 | Batch 120/192 | Cost: 1.0670
# Epoch: 021/100 Train Acc.: 64.64% | Validation Acc.: 63.20%
# Time elapsed: 7.09 min
# Epoch: 022/100 | Batch 000/192 | Cost: 0.9994
# Epoch: 022/100 | Batch 120/192 | Cost: 0.9007
# Epoch: 022/100 Train Acc.: 64.94% | Validation Acc.: 63.20%
# Time elapsed: 7.43 min
# Epoch: 023/100 | Batch 000/192 | Cost: 1.0145
# Epoch: 023/100 | Batch 120/192 | Cost: 1.0259
# Epoch: 023/100 Train Acc.: 67.81% | Validation Acc.: 65.20%
# Time elapsed: 7.77 min
# Epoch: 024/100 | Batch 000/192 | Cost: 0.9608
# Epoch: 024/100 | Batch 120/192 | Cost: 0.9766
# Epoch: 024/100 Train Acc.: 67.83% | Validation Acc.: 65.90%
# Time elapsed: 8.10 min
# Epoch: 025/100 | Batch 000/192 | Cost: 1.0127
# Epoch: 025/100 | Batch 120/192 | Cost: 0.9190
# Epoch: 025/100 Train Acc.: 68.48% | Validation Acc.: 67.10%
# Time elapsed: 8.44 min
# Epoch: 026/100 | Batch 000/192 | Cost: 0.8194
# Epoch: 026/100 | Batch 120/192 | Cost: 0.9307
# Epoch: 026/100 Train Acc.: 67.93% | Validation Acc.: 68.30%
# Time elapsed: 8.78 min
# Epoch: 027/100 | Batch 000/192 | Cost: 0.9170
# Epoch: 027/100 | Batch 120/192 | Cost: 0.8866
# Epoch: 027/100 Train Acc.: 69.60% | Validation Acc.: 67.10%
# Time elapsed: 9.11 min
# Epoch: 028/100 | Batch 000/192 | Cost: 0.8559
# Epoch: 028/100 | Batch 120/192 | Cost: 0.7366
# Epoch: 028/100 Train Acc.: 68.79% | Validation Acc.: 68.30%
# Time elapsed: 9.45 min
# Epoch: 029/100 | Batch 000/192 | Cost: 0.9155
# Epoch: 029/100 | Batch 120/192 | Cost: 0.9683
# Epoch: 029/100 Train Acc.: 69.49% | Validation Acc.: 65.90%
# Time elapsed: 9.79 min
# Epoch: 030/100 | Batch 000/192 | Cost: 0.9341
# Epoch: 030/100 | Batch 120/192 | Cost: 0.8820
# Epoch: 030/100 Train Acc.: 70.98% | Validation Acc.: 67.60%
# Time elapsed: 10.13 min
# Epoch: 031/100 | Batch 000/192 | Cost: 0.7724
# Epoch: 031/100 | Batch 120/192 | Cost: 0.7554
# Epoch: 031/100 Train Acc.: 71.14% | Validation Acc.: 68.50%
# Time elapsed: 10.47 min
# Epoch: 032/100 | Batch 000/192 | Cost: 0.8205
# Epoch: 032/100 | Batch 120/192 | Cost: 0.8623
# Epoch: 032/100 Train Acc.: 71.59% | Validation Acc.: 68.10%
# Time elapsed: 10.80 min
# Epoch: 033/100 | Batch 000/192 | Cost: 0.7735
# Epoch: 033/100 | Batch 120/192 | Cost: 0.8640
# Epoch: 033/100 Train Acc.: 71.51% | Validation Acc.: 70.00%
# Time elapsed: 11.14 min
# Epoch: 034/100 | Batch 000/192 | Cost: 0.8413
# Epoch: 034/100 | Batch 120/192 | Cost: 0.6812
# Epoch: 034/100 Train Acc.: 71.79% | Validation Acc.: 69.10%
# Time elapsed: 11.48 min
# Epoch: 035/100 | Batch 000/192 | Cost: 0.8989
# Epoch: 035/100 | Batch 120/192 | Cost: 0.8966
# Epoch: 035/100 Train Acc.: 72.58% | Validation Acc.: 70.10%
# Time elapsed: 11.82 min
# Epoch: 036/100 | Batch 000/192 | Cost: 0.7702
# Epoch: 036/100 | Batch 120/192 | Cost: 0.8739
# Epoch: 036/100 Train Acc.: 72.79% | Validation Acc.: 69.80%
# Time elapsed: 12.15 min
# Epoch: 037/100 | Batch 000/192 | Cost: 0.7772
# Epoch: 037/100 | Batch 120/192 | Cost: 0.7022
# Epoch: 037/100 Train Acc.: 73.50% | Validation Acc.: 70.80%
# Time elapsed: 12.49 min
# Epoch: 038/100 | Batch 000/192 | Cost: 0.7349
# Epoch: 038/100 | Batch 120/192 | Cost: 0.7438
# Epoch: 038/100 Train Acc.: 74.09% | Validation Acc.: 70.40%
# Time elapsed: 12.83 min
# Epoch: 039/100 | Batch 000/192 | Cost: 0.7220
# Epoch: 039/100 | Batch 120/192 | Cost: 0.7795
# Epoch: 039/100 Train Acc.: 73.83% | Validation Acc.: 69.10%
# Time elapsed: 13.16 min
# Epoch: 040/100 | Batch 000/192 | Cost: 0.8185
# Epoch: 040/100 | Batch 120/192 | Cost: 0.6984
# Epoch: 040/100 Train Acc.: 74.25% | Validation Acc.: 71.70%
# Time elapsed: 13.50 min
# Epoch: 041/100 | Batch 000/192 | Cost: 0.6760
# Epoch: 041/100 | Batch 120/192 | Cost: 0.8673
# Epoch: 041/100 Train Acc.: 74.26% | Validation Acc.: 70.10%
# Time elapsed: 13.84 min
# Epoch: 042/100 | Batch 000/192 | Cost: 0.7651
# Epoch: 042/100 | Batch 120/192 | Cost: 0.8110
# Epoch: 042/100 Train Acc.: 75.28% | Validation Acc.: 69.80%
# Time elapsed: 14.17 min
# Epoch: 043/100 | Batch 000/192 | Cost: 0.7613
# Epoch: 043/100 | Batch 120/192 | Cost: 0.7680
# Epoch: 043/100 Train Acc.: 74.89% | Validation Acc.: 71.30%
# Time elapsed: 14.51 min
# Epoch: 044/100 | Batch 000/192 | Cost: 0.7727
# Epoch: 044/100 | Batch 120/192 | Cost: 0.7951
# Epoch: 044/100 Train Acc.: 75.00% | Validation Acc.: 71.50%
# Time elapsed: 14.85 min
# Epoch: 045/100 | Batch 000/192 | Cost: 0.7168
# Epoch: 045/100 | Batch 120/192 | Cost: 0.7493
# Epoch: 045/100 Train Acc.: 76.02% | Validation Acc.: 71.60%
# Time elapsed: 15.19 min
# Epoch: 046/100 | Batch 000/192 | Cost: 0.6191
# Epoch: 046/100 | Batch 120/192 | Cost: 0.6574
# Epoch: 046/100 Train Acc.: 75.86% | Validation Acc.: 71.00%
# Time elapsed: 15.52 min
# Epoch: 047/100 | Batch 000/192 | Cost: 0.7041
# Epoch: 047/100 | Batch 120/192 | Cost: 0.6676
# Epoch: 047/100 Train Acc.: 76.36% | Validation Acc.: 71.00%
# Time elapsed: 15.86 min
# Epoch: 048/100 | Batch 000/192 | Cost: 0.6867
# Epoch: 048/100 | Batch 120/192 | Cost: 0.7413
# Epoch: 048/100 Train Acc.: 75.81% | Validation Acc.: 70.90%
# Time elapsed: 16.20 min
# Epoch: 049/100 | Batch 000/192 | Cost: 0.6400
# Epoch: 049/100 | Batch 120/192 | Cost: 0.6616
# Epoch: 049/100 Train Acc.: 77.20% | Validation Acc.: 71.60%
# Time elapsed: 16.53 min
# Epoch: 050/100 | Batch 000/192 | Cost: 0.5869
# Epoch: 050/100 | Batch 120/192 | Cost: 0.7880
# Epoch: 050/100 Train Acc.: 76.54% | Validation Acc.: 73.80%
# Time elapsed: 16.87 min
# Epoch: 051/100 | Batch 000/192 | Cost: 0.6346
# Epoch: 051/100 | Batch 120/192 | Cost: 0.7546
# Epoch: 051/100 Train Acc.: 76.56% | Validation Acc.: 71.40%
# Time elapsed: 17.21 min
# Epoch: 052/100 | Batch 000/192 | Cost: 0.7384
# Epoch: 052/100 | Batch 120/192 | Cost: 0.6931
# Epoch: 052/100 Train Acc.: 78.14% | Validation Acc.: 72.40%
# Time elapsed: 17.54 min
# Epoch: 053/100 | Batch 000/192 | Cost: 0.6469
# Epoch: 053/100 | Batch 120/192 | Cost: 0.5473
# Epoch: 053/100 Train Acc.: 77.86% | Validation Acc.: 72.40%
# Time elapsed: 17.88 min
# Epoch: 054/100 | Batch 000/192 | Cost: 0.7120
# Epoch: 054/100 | Batch 120/192 | Cost: 0.6427
# Epoch: 054/100 Train Acc.: 77.65% | Validation Acc.: 70.70%
# Time elapsed: 18.22 min
# Epoch: 055/100 | Batch 000/192 | Cost: 0.6419
# Epoch: 055/100 | Batch 120/192 | Cost: 0.6030
# Epoch: 055/100 Train Acc.: 78.88% | Validation Acc.: 72.70%
# Time elapsed: 18.55 min
# Epoch: 056/100 | Batch 000/192 | Cost: 0.6753
# Epoch: 056/100 | Batch 120/192 | Cost: 0.6162
# Epoch: 056/100 Train Acc.: 78.55% | Validation Acc.: 72.20%
# Time elapsed: 18.89 min
# Epoch: 057/100 | Batch 000/192 | Cost: 0.6220
# Epoch: 057/100 | Batch 120/192 | Cost: 0.5362
# Epoch: 057/100 Train Acc.: 78.40% | Validation Acc.: 71.90%
# Time elapsed: 19.23 min
# Epoch: 058/100 | Batch 000/192 | Cost: 0.6182
# Epoch: 058/100 | Batch 120/192 | Cost: 0.6040
# Epoch: 058/100 Train Acc.: 79.04% | Validation Acc.: 72.20%
# Time elapsed: 19.57 min
# Epoch: 059/100 | Batch 000/192 | Cost: 0.5566
# Epoch: 059/100 | Batch 120/192 | Cost: 0.5750
# Epoch: 059/100 Train Acc.: 77.68% | Validation Acc.: 72.10%
# Time elapsed: 19.92 min
# Epoch: 060/100 | Batch 000/192 | Cost: 0.5580
# Epoch: 060/100 | Batch 120/192 | Cost: 0.6459
# Epoch: 060/100 Train Acc.: 79.08% | Validation Acc.: 72.10%
# Time elapsed: 20.28 min
# Epoch: 061/100 | Batch 000/192 | Cost: 0.5860
# Epoch: 061/100 | Batch 120/192 | Cost: 0.4901
# Epoch: 061/100 Train Acc.: 79.58% | Validation Acc.: 72.60%
# Time elapsed: 20.63 min
# Epoch: 062/100 | Batch 000/192 | Cost: 0.6107
# Epoch: 062/100 | Batch 120/192 | Cost: 0.5956
# Epoch: 062/100 Train Acc.: 79.17% | Validation Acc.: 71.70%
# Time elapsed: 20.98 min
# Epoch: 063/100 | Batch 000/192 | Cost: 0.6433
# Epoch: 063/100 | Batch 120/192 | Cost: 0.6782
# Epoch: 063/100 Train Acc.: 79.71% | Validation Acc.: 72.20%
# Time elapsed: 21.33 min
# Epoch: 064/100 | Batch 000/192 | Cost: 0.5472
# Epoch: 064/100 | Batch 120/192 | Cost: 0.5938
# Epoch: 064/100 Train Acc.: 80.93% | Validation Acc.: 73.40%
# Time elapsed: 21.68 min
# Epoch: 065/100 | Batch 000/192 | Cost: 0.4908
# Epoch: 065/100 | Batch 120/192 | Cost: 0.6274
# Epoch: 065/100 Train Acc.: 79.95% | Validation Acc.: 72.80%
# Time elapsed: 22.04 min
# Epoch: 066/100 | Batch 000/192 | Cost: 0.6660
# Epoch: 066/100 | Batch 120/192 | Cost: 0.6161
# Epoch: 066/100 Train Acc.: 80.60% | Validation Acc.: 73.10%
# Time elapsed: 22.39 min
# Epoch: 067/100 | Batch 000/192 | Cost: 0.5471
# Epoch: 067/100 | Batch 120/192 | Cost: 0.5267
# Epoch: 067/100 Train Acc.: 80.81% | Validation Acc.: 73.20%
# Time elapsed: 22.74 min
# Epoch: 068/100 | Batch 000/192 | Cost: 0.5803
# Epoch: 068/100 | Batch 120/192 | Cost: 0.4796
# Epoch: 068/100 Train Acc.: 80.71% | Validation Acc.: 73.70%
# Time elapsed: 23.09 min
# Epoch: 069/100 | Batch 000/192 | Cost: 0.5825
# Epoch: 069/100 | Batch 120/192 | Cost: 0.6337
# Epoch: 069/100 Train Acc.: 80.92% | Validation Acc.: 73.60%
# Time elapsed: 23.44 min
# Epoch: 070/100 | Batch 000/192 | Cost: 0.5606
# Epoch: 070/100 | Batch 120/192 | Cost: 0.5830
# Epoch: 070/100 Train Acc.: 81.00% | Validation Acc.: 72.10%
# Time elapsed: 23.80 min
# Epoch: 071/100 | Batch 000/192 | Cost: 0.5272
# Epoch: 071/100 | Batch 120/192 | Cost: 0.4862
# Epoch: 071/100 Train Acc.: 80.99% | Validation Acc.: 72.60%
# Time elapsed: 24.15 min
# Epoch: 072/100 | Batch 000/192 | Cost: 0.4753
# Epoch: 072/100 | Batch 120/192 | Cost: 0.3925
# Epoch: 072/100 Train Acc.: 81.14% | Validation Acc.: 72.60%
# Time elapsed: 24.50 min
# Epoch: 073/100 | Batch 000/192 | Cost: 0.5307
# Epoch: 073/100 | Batch 120/192 | Cost: 0.5553
# Epoch: 073/100 Train Acc.: 80.76% | Validation Acc.: 71.80%
# Time elapsed: 24.85 min
# Epoch: 074/100 | Batch 000/192 | Cost: 0.5315
# Epoch: 074/100 | Batch 120/192 | Cost: 0.4984
# Epoch: 074/100 Train Acc.: 81.38% | Validation Acc.: 73.10%
# Time elapsed: 25.20 min
# Epoch: 075/100 | Batch 000/192 | Cost: 0.4508
# Epoch: 075/100 | Batch 120/192 | Cost: 0.5322
# Epoch: 075/100 Train Acc.: 80.56% | Validation Acc.: 73.20%
# Time elapsed: 25.55 min
# Epoch: 076/100 | Batch 000/192 | Cost: 0.5022
# Epoch: 076/100 | Batch 120/192 | Cost: 0.4590
# Epoch: 076/100 Train Acc.: 81.43% | Validation Acc.: 73.10%
# Time elapsed: 25.91 min
# Epoch: 077/100 | Batch 000/192 | Cost: 0.5534
# Epoch: 077/100 | Batch 120/192 | Cost: 0.5921
# Epoch: 077/100 Train Acc.: 82.41% | Validation Acc.: 72.30%
# Time elapsed: 26.26 min
# Epoch: 078/100 | Batch 000/192 | Cost: 0.4366
# Epoch: 078/100 | Batch 120/192 | Cost: 0.4836
# Epoch: 078/100 Train Acc.: 81.57% | Validation Acc.: 71.20%
# Time elapsed: 26.61 min
# Epoch: 079/100 | Batch 000/192 | Cost: 0.4705
# Epoch: 079/100 | Batch 120/192 | Cost: 0.4931
# Epoch: 079/100 Train Acc.: 82.16% | Validation Acc.: 72.60%
# Time elapsed: 26.96 min
# Epoch: 080/100 | Batch 000/192 | Cost: 0.4767
# Epoch: 080/100 | Batch 120/192 | Cost: 0.6313
# Epoch: 080/100 Train Acc.: 82.34% | Validation Acc.: 71.30%
# Time elapsed: 27.31 min
# Epoch: 081/100 | Batch 000/192 | Cost: 0.6211
# Epoch: 081/100 | Batch 120/192 | Cost: 0.5138
# Epoch: 081/100 Train Acc.: 82.03% | Validation Acc.: 71.90%
# Time elapsed: 27.66 min
# Epoch: 082/100 | Batch 000/192 | Cost: 0.4495
# Epoch: 082/100 | Batch 120/192 | Cost: 0.4917
# Epoch: 082/100 Train Acc.: 81.23% | Validation Acc.: 71.60%
# Time elapsed: 28.02 min
# Epoch: 083/100 | Batch 000/192 | Cost: 0.3803
# Epoch: 083/100 | Batch 120/192 | Cost: 0.6247
# Epoch: 083/100 Train Acc.: 82.77% | Validation Acc.: 74.40%
# Time elapsed: 28.37 min
# Epoch: 084/100 | Batch 000/192 | Cost: 0.5032
# Epoch: 084/100 | Batch 120/192 | Cost: 0.4318
# Epoch: 084/100 Train Acc.: 82.45% | Validation Acc.: 72.90%
# Time elapsed: 28.72 min
# Epoch: 085/100 | Batch 000/192 | Cost: 0.4828
# Epoch: 085/100 | Batch 120/192 | Cost: 0.4842
# Epoch: 085/100 Train Acc.: 82.75% | Validation Acc.: 72.40%
# Time elapsed: 29.07 min
# Epoch: 086/100 | Batch 000/192 | Cost: 0.5426
# Epoch: 086/100 | Batch 120/192 | Cost: 0.5699
# Epoch: 086/100 Train Acc.: 83.32% | Validation Acc.: 73.70%
# Time elapsed: 29.42 min
# Epoch: 087/100 | Batch 000/192 | Cost: 0.4077
# Epoch: 087/100 | Batch 120/192 | Cost: 0.5206
# Epoch: 087/100 Train Acc.: 83.15% | Validation Acc.: 73.70%
# Time elapsed: 29.77 min
# Epoch: 088/100 | Batch 000/192 | Cost: 0.4867
# Epoch: 088/100 | Batch 120/192 | Cost: 0.5010
# Epoch: 088/100 Train Acc.: 82.91% | Validation Acc.: 71.80%
# Time elapsed: 30.12 min
# Epoch: 089/100 | Batch 000/192 | Cost: 0.3858
# Epoch: 089/100 | Batch 120/192 | Cost: 0.4805
# Epoch: 089/100 Train Acc.: 83.76% | Validation Acc.: 72.60%
# Time elapsed: 30.47 min
# Epoch: 090/100 | Batch 000/192 | Cost: 0.4267
# Epoch: 090/100 | Batch 120/192 | Cost: 0.4430
# Epoch: 090/100 Train Acc.: 83.42% | Validation Acc.: 72.60%
# Time elapsed: 30.83 min
# Epoch: 091/100 | Batch 000/192 | Cost: 0.4524
# Epoch: 091/100 | Batch 120/192 | Cost: 0.5378
# Epoch: 091/100 Train Acc.: 82.74% | Validation Acc.: 72.70%
# Time elapsed: 31.18 min
# Epoch: 092/100 | Batch 000/192 | Cost: 0.4259
# Epoch: 092/100 | Batch 120/192 | Cost: 0.4336
# Epoch: 092/100 Train Acc.: 84.01% | Validation Acc.: 73.40%
# Time elapsed: 31.53 min
# Epoch: 093/100 | Batch 000/192 | Cost: 0.5187
# Epoch: 093/100 | Batch 120/192 | Cost: 0.5380
# Epoch: 093/100 Train Acc.: 84.08% | Validation Acc.: 72.70%
# Time elapsed: 31.88 min
# Epoch: 094/100 | Batch 000/192 | Cost: 0.4666
# Epoch: 094/100 | Batch 120/192 | Cost: 0.4567
# Epoch: 094/100 Train Acc.: 83.87% | Validation Acc.: 72.00%
# Time elapsed: 32.23 min
# Epoch: 095/100 | Batch 000/192 | Cost: 0.5056
# Epoch: 095/100 | Batch 120/192 | Cost: 0.3520
# Epoch: 095/100 Train Acc.: 84.24% | Validation Acc.: 74.90%
# Time elapsed: 32.59 min
# Epoch: 096/100 | Batch 000/192 | Cost: 0.4989
# Epoch: 096/100 | Batch 120/192 | Cost: 0.4355
# Epoch: 096/100 Train Acc.: 83.62% | Validation Acc.: 73.20%
# Time elapsed: 32.94 min
# Epoch: 097/100 | Batch 000/192 | Cost: 0.4089
# Epoch: 097/100 | Batch 120/192 | Cost: 0.3521
# Epoch: 097/100 Train Acc.: 83.88% | Validation Acc.: 73.70%
# Time elapsed: 33.29 min
# Epoch: 098/100 | Batch 000/192 | Cost: 0.4364
# Epoch: 098/100 | Batch 120/192 | Cost: 0.4730
# Epoch: 098/100 Train Acc.: 84.07% | Validation Acc.: 73.60%
# Time elapsed: 33.64 min
# Epoch: 099/100 | Batch 000/192 | Cost: 0.5375
# Epoch: 099/100 | Batch 120/192 | Cost: 0.4485
# Epoch: 099/100 Train Acc.: 84.07% | Validation Acc.: 72.80%
# Time elapsed: 33.99 min
# Epoch: 100/100 | Batch 000/192 | Cost: 0.4016
# Epoch: 100/100 | Batch 120/192 | Cost: 0.5793
# Epoch: 100/100 Train Acc.: 82.96% | Validation Acc.: 73.40%
# Time elapsed: 34.34 min
# Total Training Time: 34.34 min

# %% [markdown]
# # 3.2.在激活函数前加入BatchNorm

# %%
class NiN(nn.Module):
    def __init__(self, num_classes):
        super(NiN, self).__init__()
        self.num_classes = num_classes
        self.classifier = nn.Sequential(
                nn.Conv2d(3, 192, kernel_size=5, stride=1, padding=2, bias=False),
                nn.BatchNorm2d(192),
                nn.ReLU(inplace=True),
                nn.Conv2d(192, 160, kernel_size=1, stride=1, padding=0, bias=False),
                nn.BatchNorm2d(160),
                nn.ReLU(inplace=True),
                nn.Conv2d(160,  96, kernel_size=1, stride=1, padding=0, bias=False),
                nn.BatchNorm2d(96),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
                nn.Dropout(0.5),

                nn.Conv2d(96, 192, kernel_size=5, stride=1, padding=2, bias=False),
                nn.BatchNorm2d(192),
                nn.ReLU(inplace=True),
                nn.Conv2d(192, 192, kernel_size=1, stride=1, padding=0, bias=False),
                nn.BatchNorm2d(192),
                nn.ReLU(inplace=True),
                nn.Conv2d(192, 192, kernel_size=1, stride=1, padding=0, bias=False),
                nn.BatchNorm2d(192),
                nn.ReLU(inplace=True),
                nn.AvgPool2d(kernel_size=3, stride=2, padding=1),
                nn.Dropout(0.5),

                nn.Conv2d(192, 192, kernel_size=3, stride=1, padding=1, bias=False),
                nn.BatchNorm2d(192),
                nn.ReLU(inplace=True),
                nn.Conv2d(192, 192, kernel_size=1, stride=1, padding=0, bias=False),
                nn.BatchNorm2d(192),
                nn.ReLU(inplace=True),
                nn.Conv2d(192,  10, kernel_size=1, stride=1, padding=0),
                nn.ReLU(inplace=True),
                nn.AvgPool2d(kernel_size=8, stride=1, padding=0),

                )

    def forward(self, x):
        x = self.classifier(x)
        logits = x.view(x.size(0), self.num_classes)
        probas = torch.softmax(logits, dim=1)
        return logits, probas

# %%
torch.manual_seed(RANDOM_SEED)

model = NiN(NUM_CLASSES)
model.to(DEVICE)

optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %%
start_time = time.time()
for epoch in range(NUM_EPOCHS):
    
    model.train()
    
    for batch_idx, (features, targets) in enumerate(train_loader):
    
        ### PREPARE MINIBATCH
        features = features.to(DEVICE)
        targets = targets.to(DEVICE)
            
        ### FORWARD AND BACK PROP
        logits, probas = model(features)
        cost = F.cross_entropy(logits, targets)
        optimizer.zero_grad()
        
        cost.backward()
        
        ### UPDATE MODEL PARAMETERS
        optimizer.step()
        
        ### LOGGING
        if not batch_idx % 120:
            print (f'Epoch: {epoch+1:03d}/{NUM_EPOCHS:03d} | '
                   f'Batch {batch_idx:03d}/{len(train_loader):03d} |' 
                   f' Cost: {cost:.4f}')

    # no need to build the computation graph for backprop when computing accuracy
    with torch.set_grad_enabled(False):
        train_acc = compute_accuracy(model, train_loader, device=DEVICE)
        valid_acc = compute_accuracy(model, valid_loader, device=DEVICE)
        print(f'Epoch: {epoch+1:03d}/{NUM_EPOCHS:03d} Train Acc.: {train_acc:.2f}%'
              f' | Validation Acc.: {valid_acc:.2f}%')
        
    elapsed = (time.time() - start_time)/60
    print(f'Time elapsed: {elapsed:.2f} min')
  
elapsed = (time.time() - start_time)/60
print(f'Total Training Time: {elapsed:.2f} min')
# Out:
# Epoch: 001/100 | Batch 000/192 | Cost: 2.3148
# Epoch: 001/100 | Batch 120/192 | Cost: 1.4051
# Epoch: 001/100 Train Acc.: 58.11% | Validation Acc.: 58.50%
# Time elapsed: 0.38 min
# Epoch: 002/100 | Batch 000/192 | Cost: 1.1883
# Epoch: 002/100 | Batch 120/192 | Cost: 1.0690
# Epoch: 002/100 Train Acc.: 66.62% | Validation Acc.: 65.40%
# Time elapsed: 0.75 min
# Epoch: 003/100 | Batch 000/192 | Cost: 0.9535
# Epoch: 003/100 | Batch 120/192 | Cost: 0.8616
# Epoch: 003/100 Train Acc.: 70.90% | Validation Acc.: 69.90%
# Time elapsed: 1.13 min
# Epoch: 004/100 | Batch 000/192 | Cost: 0.9257
# Epoch: 004/100 | Batch 120/192 | Cost: 0.7893
# Epoch: 004/100 Train Acc.: 74.34% | Validation Acc.: 74.00%
# Time elapsed: 1.51 min
# Epoch: 005/100 | Batch 000/192 | Cost: 0.7172
# Epoch: 005/100 | Batch 120/192 | Cost: 0.7068
# Epoch: 005/100 Train Acc.: 76.68% | Validation Acc.: 75.20%
# Time elapsed: 1.88 min
# Epoch: 006/100 | Batch 000/192 | Cost: 0.7002
# Epoch: 006/100 | Batch 120/192 | Cost: 0.5935
# Epoch: 006/100 Train Acc.: 79.11% | Validation Acc.: 77.10%
# Time elapsed: 2.26 min
# Epoch: 007/100 | Batch 000/192 | Cost: 0.6057
# Epoch: 007/100 | Batch 120/192 | Cost: 0.5642
# Epoch: 007/100 Train Acc.: 81.32% | Validation Acc.: 79.30%
# Time elapsed: 2.64 min
# Epoch: 008/100 | Batch 000/192 | Cost: 0.4994
# Epoch: 008/100 | Batch 120/192 | Cost: 0.5878
# Epoch: 008/100 Train Acc.: 81.97% | Validation Acc.: 79.00%
# Time elapsed: 3.01 min
# Epoch: 009/100 | Batch 000/192 | Cost: 0.5373
# Epoch: 009/100 | Batch 120/192 | Cost: 0.5209
# Epoch: 009/100 Train Acc.: 82.90% | Validation Acc.: 78.50%
# Time elapsed: 3.39 min
# Epoch: 010/100 | Batch 000/192 | Cost: 0.4955
# Epoch: 010/100 | Batch 120/192 | Cost: 0.6047
# Epoch: 010/100 Train Acc.: 84.06% | Validation Acc.: 81.10%
# Time elapsed: 3.77 min
# Epoch: 011/100 | Batch 000/192 | Cost: 0.4452
# Epoch: 011/100 | Batch 120/192 | Cost: 0.4952
# Epoch: 011/100 Train Acc.: 85.19% | Validation Acc.: 81.10%
# Time elapsed: 4.15 min
# Epoch: 012/100 | Batch 000/192 | Cost: 0.4039
# Epoch: 012/100 | Batch 120/192 | Cost: 0.5766
# Epoch: 012/100 Train Acc.: 85.79% | Validation Acc.: 81.10%
# Time elapsed: 4.52 min
# Epoch: 013/100 | Batch 000/192 | Cost: 0.3697
# Epoch: 013/100 | Batch 120/192 | Cost: 0.3779
# Epoch: 013/100 Train Acc.: 86.74% | Validation Acc.: 82.20%
# Time elapsed: 4.90 min
# Epoch: 014/100 | Batch 000/192 | Cost: 0.3304
# Epoch: 014/100 | Batch 120/192 | Cost: 0.5341
# Epoch: 014/100 Train Acc.: 87.06% | Validation Acc.: 81.40%
# Time elapsed: 5.28 min
# Epoch: 015/100 | Batch 000/192 | Cost: 0.3333
# Epoch: 015/100 | Batch 120/192 | Cost: 0.3731
# Epoch: 015/100 Train Acc.: 88.06% | Validation Acc.: 82.80%
# Time elapsed: 5.65 min
# Epoch: 016/100 | Batch 000/192 | Cost: 0.3044
# Epoch: 016/100 | Batch 120/192 | Cost: 0.3571
# Epoch: 016/100 Train Acc.: 88.36% | Validation Acc.: 82.60%
# Time elapsed: 6.03 min
# Epoch: 017/100 | Batch 000/192 | Cost: 0.3346
# Epoch: 017/100 | Batch 120/192 | Cost: 0.3364
# Epoch: 017/100 Train Acc.: 88.40% | Validation Acc.: 81.90%
# Time elapsed: 6.41 min
# Epoch: 018/100 | Batch 000/192 | Cost: 0.3178
# Epoch: 018/100 | Batch 120/192 | Cost: 0.3021
# Epoch: 018/100 Train Acc.: 89.36% | Validation Acc.: 82.80%
# Time elapsed: 6.79 min
# Epoch: 019/100 | Batch 000/192 | Cost: 0.3712
# Epoch: 019/100 | Batch 120/192 | Cost: 0.2817
# Epoch: 019/100 Train Acc.: 89.80% | Validation Acc.: 83.30%
# Time elapsed: 7.16 min
# Epoch: 020/100 | Batch 000/192 | Cost: 0.3170
# Epoch: 020/100 | Batch 120/192 | Cost: 0.2840
# Epoch: 020/100 Train Acc.: 90.19% | Validation Acc.: 82.90%
# Time elapsed: 7.54 min
# Epoch: 021/100 | Batch 000/192 | Cost: 0.2591
# Epoch: 021/100 | Batch 120/192 | Cost: 0.2706
# Epoch: 021/100 Train Acc.: 90.73% | Validation Acc.: 82.90%
# Time elapsed: 7.92 min
# Epoch: 022/100 | Batch 000/192 | Cost: 0.3314
# Epoch: 022/100 | Batch 120/192 | Cost: 0.2200
# Epoch: 022/100 Train Acc.: 91.53% | Validation Acc.: 84.70%
# Time elapsed: 8.29 min
# Epoch: 023/100 | Batch 000/192 | Cost: 0.2434
# Epoch: 023/100 | Batch 120/192 | Cost: 0.2990
# Epoch: 023/100 Train Acc.: 91.63% | Validation Acc.: 83.50%
# Time elapsed: 8.67 min
# Epoch: 024/100 | Batch 000/192 | Cost: 0.3129
# Epoch: 024/100 | Batch 120/192 | Cost: 0.2660
# Epoch: 024/100 Train Acc.: 92.08% | Validation Acc.: 83.00%
# Time elapsed: 9.05 min
# Epoch: 025/100 | Batch 000/192 | Cost: 0.2842
# Epoch: 025/100 | Batch 120/192 | Cost: 0.2439
# Epoch: 025/100 Train Acc.: 92.57% | Validation Acc.: 83.10%
# Time elapsed: 9.43 min
# Epoch: 026/100 | Batch 000/192 | Cost: 0.1995
# Epoch: 026/100 | Batch 120/192 | Cost: 0.2592
# Epoch: 026/100 Train Acc.: 92.56% | Validation Acc.: 83.30%
# Time elapsed: 9.80 min
# Epoch: 027/100 | Batch 000/192 | Cost: 0.2603
# Epoch: 027/100 | Batch 120/192 | Cost: 0.2411
# Epoch: 027/100 Train Acc.: 93.07% | Validation Acc.: 84.30%
# Time elapsed: 10.18 min
# Epoch: 028/100 | Batch 000/192 | Cost: 0.1366
# Epoch: 028/100 | Batch 120/192 | Cost: 0.1680
# Epoch: 028/100 Train Acc.: 93.19% | Validation Acc.: 83.00%
# Time elapsed: 10.56 min
# Epoch: 029/100 | Batch 000/192 | Cost: 0.1848
# Epoch: 029/100 | Batch 120/192 | Cost: 0.1426
# Epoch: 029/100 Train Acc.: 93.57% | Validation Acc.: 84.90%
# Time elapsed: 10.94 min
# Epoch: 030/100 | Batch 000/192 | Cost: 0.2435
# Epoch: 030/100 | Batch 120/192 | Cost: 0.1822
# Epoch: 030/100 Train Acc.: 93.49% | Validation Acc.: 83.00%
# Time elapsed: 11.31 min
# Epoch: 031/100 | Batch 000/192 | Cost: 0.1986
# Epoch: 031/100 | Batch 120/192 | Cost: 0.1840
# Epoch: 031/100 Train Acc.: 94.28% | Validation Acc.: 83.00%
# Time elapsed: 11.69 min
# Epoch: 032/100 | Batch 000/192 | Cost: 0.1414
# Epoch: 032/100 | Batch 120/192 | Cost: 0.1873
# Epoch: 032/100 Train Acc.: 94.20% | Validation Acc.: 83.40%
# Time elapsed: 12.07 min
# Epoch: 033/100 | Batch 000/192 | Cost: 0.1398
# Epoch: 033/100 | Batch 120/192 | Cost: 0.1991
# Epoch: 033/100 Train Acc.: 94.86% | Validation Acc.: 83.50%
# Time elapsed: 12.45 min
# Epoch: 034/100 | Batch 000/192 | Cost: 0.0940
# Epoch: 034/100 | Batch 120/192 | Cost: 0.1543
# Epoch: 034/100 Train Acc.: 94.84% | Validation Acc.: 84.80%
# Time elapsed: 12.82 min
# Epoch: 035/100 | Batch 000/192 | Cost: 0.1601
# Epoch: 035/100 | Batch 120/192 | Cost: 0.1955
# Epoch: 035/100 Train Acc.: 94.90% | Validation Acc.: 84.40%
# Time elapsed: 13.20 min
# Epoch: 036/100 | Batch 000/192 | Cost: 0.1908
# Epoch: 036/100 | Batch 120/192 | Cost: 0.1628
# Epoch: 036/100 Train Acc.: 94.91% | Validation Acc.: 84.10%
# Time elapsed: 13.58 min
# Epoch: 037/100 | Batch 000/192 | Cost: 0.1206
# Epoch: 037/100 | Batch 120/192 | Cost: 0.1354
# Epoch: 037/100 Train Acc.: 94.50% | Validation Acc.: 84.30%
# Time elapsed: 13.96 min
# Epoch: 038/100 | Batch 000/192 | Cost: 0.1471
# Epoch: 038/100 | Batch 120/192 | Cost: 0.1687
# Epoch: 038/100 Train Acc.: 95.16% | Validation Acc.: 84.80%
# Time elapsed: 14.34 min
# Epoch: 039/100 | Batch 000/192 | Cost: 0.1326
# Epoch: 039/100 | Batch 120/192 | Cost: 0.1548
# Epoch: 039/100 Train Acc.: 95.26% | Validation Acc.: 83.40%
# Time elapsed: 14.71 min
# Epoch: 040/100 | Batch 000/192 | Cost: 0.1802
# Epoch: 040/100 | Batch 120/192 | Cost: 0.1176
# Epoch: 040/100 Train Acc.: 95.10% | Validation Acc.: 84.80%
# Time elapsed: 15.09 min
# Epoch: 041/100 | Batch 000/192 | Cost: 0.1408
# Epoch: 041/100 | Batch 120/192 | Cost: 0.1785
# Epoch: 041/100 Train Acc.: 95.64% | Validation Acc.: 85.10%
# Time elapsed: 15.47 min
# Epoch: 042/100 | Batch 000/192 | Cost: 0.0884
# Epoch: 042/100 | Batch 120/192 | Cost: 0.1354
# Epoch: 042/100 Train Acc.: 96.14% | Validation Acc.: 84.70%
# Time elapsed: 15.85 min
# Epoch: 043/100 | Batch 000/192 | Cost: 0.0546
# Epoch: 043/100 | Batch 120/192 | Cost: 0.1728
# Epoch: 043/100 Train Acc.: 96.01% | Validation Acc.: 83.90%
# Time elapsed: 16.23 min
# Epoch: 044/100 | Batch 000/192 | Cost: 0.1165
# Epoch: 044/100 | Batch 120/192 | Cost: 0.1189
# Epoch: 044/100 Train Acc.: 96.01% | Validation Acc.: 84.40%
# Time elapsed: 16.61 min
# Epoch: 045/100 | Batch 000/192 | Cost: 0.0711
# Epoch: 045/100 | Batch 120/192 | Cost: 0.1783
# Epoch: 045/100 Train Acc.: 95.86% | Validation Acc.: 83.50%
# Time elapsed: 16.98 min
# Epoch: 046/100 | Batch 000/192 | Cost: 0.0777
# Epoch: 046/100 | Batch 120/192 | Cost: 0.0884
# Epoch: 046/100 Train Acc.: 96.45% | Validation Acc.: 84.30%
# Time elapsed: 17.36 min
# Epoch: 047/100 | Batch 000/192 | Cost: 0.0821
# Epoch: 047/100 | Batch 120/192 | Cost: 0.0904
# Epoch: 047/100 Train Acc.: 96.47% | Validation Acc.: 85.60%
# Time elapsed: 17.74 min
# Epoch: 048/100 | Batch 000/192 | Cost: 0.0755
# Epoch: 048/100 | Batch 120/192 | Cost: 0.1599
# Epoch: 048/100 Train Acc.: 96.39% | Validation Acc.: 85.40%
# Time elapsed: 18.11 min
# Epoch: 049/100 | Batch 000/192 | Cost: 0.1242
# Epoch: 049/100 | Batch 120/192 | Cost: 0.1270
# Epoch: 049/100 Train Acc.: 96.21% | Validation Acc.: 83.40%
# Time elapsed: 18.49 min
# Epoch: 050/100 | Batch 000/192 | Cost: 0.1395
# Epoch: 050/100 | Batch 120/192 | Cost: 0.0981
# Epoch: 050/100 Train Acc.: 96.66% | Validation Acc.: 85.00%
# Time elapsed: 18.86 min
# Epoch: 051/100 | Batch 000/192 | Cost: 0.0861
# Epoch: 051/100 | Batch 120/192 | Cost: 0.0734
# Epoch: 051/100 Train Acc.: 96.63% | Validation Acc.: 83.90%
# Time elapsed: 19.24 min
# Epoch: 052/100 | Batch 000/192 | Cost: 0.0867
# Epoch: 052/100 | Batch 120/192 | Cost: 0.1450
# Epoch: 052/100 Train Acc.: 96.70% | Validation Acc.: 84.90%
# Time elapsed: 19.62 min
# Epoch: 053/100 | Batch 000/192 | Cost: 0.1015
# Epoch: 053/100 | Batch 120/192 | Cost: 0.0595
# Epoch: 053/100 Train Acc.: 96.86% | Validation Acc.: 84.70%
# Time elapsed: 20.00 min
# Epoch: 054/100 | Batch 000/192 | Cost: 0.0786
# Epoch: 054/100 | Batch 120/192 | Cost: 0.1135
# Epoch: 054/100 Train Acc.: 96.87% | Validation Acc.: 84.30%
# Time elapsed: 20.37 min
# Epoch: 055/100 | Batch 000/192 | Cost: 0.0587
# Epoch: 055/100 | Batch 120/192 | Cost: 0.1275
# Epoch: 055/100 Train Acc.: 96.83% | Validation Acc.: 84.60%
# Time elapsed: 20.75 min
# Epoch: 056/100 | Batch 000/192 | Cost: 0.1455
# Epoch: 056/100 | Batch 120/192 | Cost: 0.1116
# Epoch: 056/100 Train Acc.: 97.01% | Validation Acc.: 84.60%
# Time elapsed: 21.13 min
# Epoch: 057/100 | Batch 000/192 | Cost: 0.1026
# Epoch: 057/100 | Batch 120/192 | Cost: 0.0677
# Epoch: 057/100 Train Acc.: 96.77% | Validation Acc.: 84.40%
# Time elapsed: 21.51 min
# Epoch: 058/100 | Batch 000/192 | Cost: 0.0837
# Epoch: 058/100 | Batch 120/192 | Cost: 0.1183
# Epoch: 058/100 Train Acc.: 97.32% | Validation Acc.: 85.70%
# Time elapsed: 21.89 min
# Epoch: 059/100 | Batch 000/192 | Cost: 0.1112
# Epoch: 059/100 | Batch 120/192 | Cost: 0.0977
# Epoch: 059/100 Train Acc.: 97.25% | Validation Acc.: 84.30%
# Time elapsed: 22.26 min
# Epoch: 060/100 | Batch 000/192 | Cost: 0.0572
# Epoch: 060/100 | Batch 120/192 | Cost: 0.1143
# Epoch: 060/100 Train Acc.: 97.32% | Validation Acc.: 84.00%
# Time elapsed: 22.64 min
# Epoch: 061/100 | Batch 000/192 | Cost: 0.1097
# Epoch: 061/100 | Batch 120/192 | Cost: 0.0888
# Epoch: 061/100 Train Acc.: 97.16% | Validation Acc.: 84.20%
# Time elapsed: 23.02 min
# Epoch: 062/100 | Batch 000/192 | Cost: 0.0785
# Epoch: 062/100 | Batch 120/192 | Cost: 0.1092
# Epoch: 062/100 Train Acc.: 97.18% | Validation Acc.: 85.00%
# Time elapsed: 23.39 min
# Epoch: 063/100 | Batch 000/192 | Cost: 0.0942
# Epoch: 063/100 | Batch 120/192 | Cost: 0.0492
# Epoch: 063/100 Train Acc.: 97.34% | Validation Acc.: 84.70%
# Time elapsed: 23.77 min
# Epoch: 064/100 | Batch 000/192 | Cost: 0.0484
# Epoch: 064/100 | Batch 120/192 | Cost: 0.0580
# Epoch: 064/100 Train Acc.: 97.30% | Validation Acc.: 83.70%
# Time elapsed: 24.15 min
# Epoch: 065/100 | Batch 000/192 | Cost: 0.0560
# Epoch: 065/100 | Batch 120/192 | Cost: 0.0925
# Epoch: 065/100 Train Acc.: 96.93% | Validation Acc.: 84.40%
# Time elapsed: 24.53 min
# Epoch: 066/100 | Batch 000/192 | Cost: 0.0724
# Epoch: 066/100 | Batch 120/192 | Cost: 0.0734
# Epoch: 066/100 Train Acc.: 97.58% | Validation Acc.: 84.80%
# Time elapsed: 24.91 min
# Epoch: 067/100 | Batch 000/192 | Cost: 0.0412
# Epoch: 067/100 | Batch 120/192 | Cost: 0.0711
# Epoch: 067/100 Train Acc.: 97.19% | Validation Acc.: 85.40%
# Time elapsed: 25.28 min
# Epoch: 068/100 | Batch 000/192 | Cost: 0.0554
# Epoch: 068/100 | Batch 120/192 | Cost: 0.0378
# Epoch: 068/100 Train Acc.: 97.52% | Validation Acc.: 83.40%
# Time elapsed: 25.66 min
# Epoch: 069/100 | Batch 000/192 | Cost: 0.0848
# Epoch: 069/100 | Batch 120/192 | Cost: 0.1210
# Epoch: 069/100 Train Acc.: 97.53% | Validation Acc.: 83.70%
# Time elapsed: 26.04 min
# Epoch: 070/100 | Batch 000/192 | Cost: 0.0648
# Epoch: 070/100 | Batch 120/192 | Cost: 0.0771
# Epoch: 070/100 Train Acc.: 97.68% | Validation Acc.: 85.90%
# Time elapsed: 26.41 min
# Epoch: 071/100 | Batch 000/192 | Cost: 0.0521
# Epoch: 071/100 | Batch 120/192 | Cost: 0.1043
# Epoch: 071/100 Train Acc.: 97.43% | Validation Acc.: 85.30%
# Time elapsed: 26.79 min
# Epoch: 072/100 | Batch 000/192 | Cost: 0.0659
# Epoch: 072/100 | Batch 120/192 | Cost: 0.0491
# Epoch: 072/100 Train Acc.: 97.56% | Validation Acc.: 86.30%
# Time elapsed: 27.17 min
# Epoch: 073/100 | Batch 000/192 | Cost: 0.0601
# Epoch: 073/100 | Batch 120/192 | Cost: 0.1008
# Epoch: 073/100 Train Acc.: 97.68% | Validation Acc.: 85.80%
# Time elapsed: 27.54 min
# Epoch: 074/100 | Batch 000/192 | Cost: 0.0703
# Epoch: 074/100 | Batch 120/192 | Cost: 0.0584
# Epoch: 074/100 Train Acc.: 97.52% | Validation Acc.: 84.40%
# Time elapsed: 27.92 min
# Epoch: 075/100 | Batch 000/192 | Cost: 0.0454
# Epoch: 075/100 | Batch 120/192 | Cost: 0.1341
# Epoch: 075/100 Train Acc.: 97.69% | Validation Acc.: 84.40%
# Time elapsed: 28.30 min
# Epoch: 076/100 | Batch 000/192 | Cost: 0.0420
# Epoch: 076/100 | Batch 120/192 | Cost: 0.1289
# Epoch: 076/100 Train Acc.: 97.88% | Validation Acc.: 85.30%
# Time elapsed: 28.68 min
# Epoch: 077/100 | Batch 000/192 | Cost: 0.0759
# Epoch: 077/100 | Batch 120/192 | Cost: 0.0762
# Epoch: 077/100 Train Acc.: 97.81% | Validation Acc.: 85.60%
# Time elapsed: 29.05 min
# Epoch: 078/100 | Batch 000/192 | Cost: 0.0744
# Epoch: 078/100 | Batch 120/192 | Cost: 0.0769
# Epoch: 078/100 Train Acc.: 97.77% | Validation Acc.: 84.80%
# Time elapsed: 29.43 min
# Epoch: 079/100 | Batch 000/192 | Cost: 0.0386
# Epoch: 079/100 | Batch 120/192 | Cost: 0.0831
# Epoch: 079/100 Train Acc.: 97.88% | Validation Acc.: 84.20%
# Time elapsed: 29.81 min
# Epoch: 080/100 | Batch 000/192 | Cost: 0.0759
# Epoch: 080/100 | Batch 120/192 | Cost: 0.1355
# Epoch: 080/100 Train Acc.: 97.66% | Validation Acc.: 82.40%
# Time elapsed: 30.18 min
# Epoch: 081/100 | Batch 000/192 | Cost: 0.0391
# Epoch: 081/100 | Batch 120/192 | Cost: 0.1091
# Epoch: 081/100 Train Acc.: 97.76% | Validation Acc.: 85.90%
# Time elapsed: 30.56 min
# Epoch: 082/100 | Batch 000/192 | Cost: 0.0719
# Epoch: 082/100 | Batch 120/192 | Cost: 0.0453
# Epoch: 082/100 Train Acc.: 98.08% | Validation Acc.: 84.80%
# Time elapsed: 30.94 min
# Epoch: 083/100 | Batch 000/192 | Cost: 0.0574
# Epoch: 083/100 | Batch 120/192 | Cost: 0.0861
# Epoch: 083/100 Train Acc.: 97.66% | Validation Acc.: 84.80%
# Time elapsed: 31.31 min
# Epoch: 084/100 | Batch 000/192 | Cost: 0.0381
# Epoch: 084/100 | Batch 120/192 | Cost: 0.0521
# Epoch: 084/100 Train Acc.: 97.79% | Validation Acc.: 86.40%
# Time elapsed: 31.69 min
# Epoch: 085/100 | Batch 000/192 | Cost: 0.0473
# Epoch: 085/100 | Batch 120/192 | Cost: 0.0709
# Epoch: 085/100 Train Acc.: 98.04% | Validation Acc.: 86.70%
# Time elapsed: 32.07 min
# Epoch: 086/100 | Batch 000/192 | Cost: 0.0479
# Epoch: 086/100 | Batch 120/192 | Cost: 0.0675
# Epoch: 086/100 Train Acc.: 97.90% | Validation Acc.: 85.30%
# Time elapsed: 32.44 min
# Epoch: 087/100 | Batch 000/192 | Cost: 0.0513
# Epoch: 087/100 | Batch 120/192 | Cost: 0.0527
# Epoch: 087/100 Train Acc.: 97.89% | Validation Acc.: 85.30%
# Time elapsed: 32.82 min
# Epoch: 088/100 | Batch 000/192 | Cost: 0.0286
# Epoch: 088/100 | Batch 120/192 | Cost: 0.0697
# Epoch: 088/100 Train Acc.: 97.78% | Validation Acc.: 84.70%
# Time elapsed: 33.19 min
# Epoch: 089/100 | Batch 000/192 | Cost: 0.0344
# Epoch: 089/100 | Batch 120/192 | Cost: 0.0502
# Epoch: 089/100 Train Acc.: 98.07% | Validation Acc.: 86.20%
# Time elapsed: 33.57 min
# Epoch: 090/100 | Batch 000/192 | Cost: 0.0301
# Epoch: 090/100 | Batch 120/192 | Cost: 0.0544
# Epoch: 090/100 Train Acc.: 97.90% | Validation Acc.: 84.70%
# Time elapsed: 33.95 min
# Epoch: 091/100 | Batch 000/192 | Cost: 0.0622
# Epoch: 091/100 | Batch 120/192 | Cost: 0.0933
# Epoch: 091/100 Train Acc.: 98.07% | Validation Acc.: 84.90%
# Time elapsed: 34.32 min
# Epoch: 092/100 | Batch 000/192 | Cost: 0.0854
# Epoch: 092/100 | Batch 120/192 | Cost: 0.0267
# Epoch: 092/100 Train Acc.: 98.06% | Validation Acc.: 84.40%
# Time elapsed: 34.70 min
# Epoch: 093/100 | Batch 000/192 | Cost: 0.0680
# Epoch: 093/100 | Batch 120/192 | Cost: 0.0557
# Epoch: 093/100 Train Acc.: 98.14% | Validation Acc.: 84.20%
# Time elapsed: 35.08 min
# Epoch: 094/100 | Batch 000/192 | Cost: 0.0808
# Epoch: 094/100 | Batch 120/192 | Cost: 0.0629
# Epoch: 094/100 Train Acc.: 98.12% | Validation Acc.: 84.20%
# Time elapsed: 35.46 min
# Epoch: 095/100 | Batch 000/192 | Cost: 0.0541
# Epoch: 095/100 | Batch 120/192 | Cost: 0.0459
# Epoch: 095/100 Train Acc.: 98.22% | Validation Acc.: 85.60%
# Time elapsed: 35.83 min
# Epoch: 096/100 | Batch 000/192 | Cost: 0.0590
# Epoch: 096/100 | Batch 120/192 | Cost: 0.0800
# Epoch: 096/100 Train Acc.: 98.03% | Validation Acc.: 85.50%
# Time elapsed: 36.21 min
# Epoch: 097/100 | Batch 000/192 | Cost: 0.0338
# Epoch: 097/100 | Batch 120/192 | Cost: 0.0769
# Epoch: 097/100 Train Acc.: 98.19% | Validation Acc.: 85.80%
# Time elapsed: 36.59 min
# Epoch: 098/100 | Batch 000/192 | Cost: 0.0506
# Epoch: 098/100 | Batch 120/192 | Cost: 0.0550
# Epoch: 098/100 Train Acc.: 98.07% | Validation Acc.: 86.00%
# Time elapsed: 36.96 min
# Epoch: 099/100 | Batch 000/192 | Cost: 0.0348
# Epoch: 099/100 | Batch 120/192 | Cost: 0.0643
# Epoch: 099/100 Train Acc.: 98.17% | Validation Acc.: 86.40%
# Time elapsed: 37.34 min
# Epoch: 100/100 | Batch 000/192 | Cost: 0.0334
# Epoch: 100/100 | Batch 120/192 | Cost: 0.0745
# Epoch: 100/100 Train Acc.: 98.13% | Validation Acc.: 86.70%
# Time elapsed: 37.72 min
# Total Training Time: 37.72 min

# %% [markdown]
# ## 3.3.在激活函数后加入BatchNorm

# %%
class NiN(nn.Module):
    def __init__(self, num_classes):
        super(NiN, self).__init__()
        self.num_classes = num_classes
        self.classifier = nn.Sequential(
                nn.Conv2d(3, 192, kernel_size=5, stride=1, padding=2, bias=False),
                nn.ReLU(inplace=True),
                nn.BatchNorm2d(192),
                nn.Conv2d(192, 160, kernel_size=1, stride=1, padding=0, bias=False),
                nn.ReLU(inplace=True),
                nn.BatchNorm2d(160),
                nn.Conv2d(160,  96, kernel_size=1, stride=1, padding=0, bias=False),
                nn.ReLU(inplace=True),
                nn.BatchNorm2d(96),
                nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
                nn.Dropout(0.5),

                nn.Conv2d(96, 192, kernel_size=5, stride=1, padding=2, bias=False),
                nn.ReLU(inplace=True),
                nn.BatchNorm2d(192),
                nn.Conv2d(192, 192, kernel_size=1, stride=1, padding=0, bias=False),
                nn.ReLU(inplace=True),
                nn.BatchNorm2d(192),
                nn.Conv2d(192, 192, kernel_size=1, stride=1, padding=0, bias=False),
                nn.ReLU(inplace=True),
                nn.BatchNorm2d(192),
                nn.AvgPool2d(kernel_size=3, stride=2, padding=1),
                nn.Dropout(0.5),

                nn.Conv2d(192, 192, kernel_size=3, stride=1, padding=1, bias=False),
                nn.ReLU(inplace=True),
                nn.BatchNorm2d(192),
                nn.Conv2d(192, 192, kernel_size=1, stride=1, padding=0, bias=False),
                nn.ReLU(inplace=True),
                nn.BatchNorm2d(192),
                nn.Conv2d(192,  10, kernel_size=1, stride=1, padding=0),
                nn.ReLU(inplace=True),
                nn.AvgPool2d(kernel_size=8, stride=1, padding=0),

                )

    def forward(self, x):
        x = self.classifier(x)
        logits = x.view(x.size(0), self.num_classes)
        probas = torch.softmax(logits, dim=1)
        return logits, probas

# %%
torch.manual_seed(RANDOM_SEED)

model = NiN(NUM_CLASSES)
model.to(DEVICE)

optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %%
start_time = time.time()
for epoch in range(NUM_EPOCHS):
    
    model.train()
    
    for batch_idx, (features, targets) in enumerate(train_loader):
    
        ### PREPARE MINIBATCH
        features = features.to(DEVICE)
        targets = targets.to(DEVICE)
            
        ### FORWARD AND BACK PROP
        logits, probas = model(features)
        cost = F.cross_entropy(logits, targets)
        optimizer.zero_grad()
        
        cost.backward()
        
        ### UPDATE MODEL PARAMETERS
        optimizer.step()
        
        ### LOGGING
        if not batch_idx % 120:
            print (f'Epoch: {epoch+1:03d}/{NUM_EPOCHS:03d} | '
                   f'Batch {batch_idx:03d}/{len(train_loader):03d} |' 
                   f' Cost: {cost:.4f}')

    # no need to build the computation graph for backprop when computing accuracy
    with torch.set_grad_enabled(False):
        train_acc = compute_accuracy(model, train_loader, device=DEVICE)
        valid_acc = compute_accuracy(model, valid_loader, device=DEVICE)
        print(f'Epoch: {epoch+1:03d}/{NUM_EPOCHS:03d} Train Acc.: {train_acc:.2f}%'
              f' | Validation Acc.: {valid_acc:.2f}%')
        
    elapsed = (time.time() - start_time)/60
    print(f'Time elapsed: {elapsed:.2f} min')
  
elapsed = (time.time() - start_time)/60
print(f'Total Training Time: {elapsed:.2f} min')
# Out:
# Epoch: 001/100 | Batch 000/192 | Cost: 2.3156
# Epoch: 001/100 | Batch 120/192 | Cost: 1.3044
# Epoch: 001/100 Train Acc.: 62.11% | Validation Acc.: 62.60%
# Time elapsed: 0.37 min
# Epoch: 002/100 | Batch 000/192 | Cost: 1.0337
# Epoch: 002/100 | Batch 120/192 | Cost: 1.0200
# Epoch: 002/100 Train Acc.: 69.12% | Validation Acc.: 68.20%
# Time elapsed: 0.75 min
# Epoch: 003/100 | Batch 000/192 | Cost: 0.8587
# Epoch: 003/100 | Batch 120/192 | Cost: 0.7816
# Epoch: 003/100 Train Acc.: 74.38% | Validation Acc.: 73.30%
# Time elapsed: 1.12 min
# Epoch: 004/100 | Batch 000/192 | Cost: 0.8238
# Epoch: 004/100 | Batch 120/192 | Cost: 0.7435
# Epoch: 004/100 Train Acc.: 77.92% | Validation Acc.: 76.80%
# Time elapsed: 1.50 min
# Epoch: 005/100 | Batch 000/192 | Cost: 0.6268
# Epoch: 005/100 | Batch 120/192 | Cost: 0.6444
# Epoch: 005/100 Train Acc.: 80.63% | Validation Acc.: 77.50%
# Time elapsed: 1.88 min
# Epoch: 006/100 | Batch 000/192 | Cost: 0.6143
# Epoch: 006/100 | Batch 120/192 | Cost: 0.4961
# Epoch: 006/100 Train Acc.: 82.33% | Validation Acc.: 78.60%
# Time elapsed: 2.25 min
# Epoch: 007/100 | Batch 000/192 | Cost: 0.5669
# Epoch: 007/100 | Batch 120/192 | Cost: 0.4981
# Epoch: 007/100 Train Acc.: 84.40% | Validation Acc.: 78.40%
# Time elapsed: 2.63 min
# Epoch: 008/100 | Batch 000/192 | Cost: 0.4073
# Epoch: 008/100 | Batch 120/192 | Cost: 0.4783
# Epoch: 008/100 Train Acc.: 84.31% | Validation Acc.: 79.00%
# Time elapsed: 3.00 min
# Epoch: 009/100 | Batch 000/192 | Cost: 0.4378
# Epoch: 009/100 | Batch 120/192 | Cost: 0.4164
# Epoch: 009/100 Train Acc.: 86.38% | Validation Acc.: 80.40%
# Time elapsed: 3.38 min
# Epoch: 010/100 | Batch 000/192 | Cost: 0.3479
# Epoch: 010/100 | Batch 120/192 | Cost: 0.3847
# Epoch: 010/100 Train Acc.: 87.77% | Validation Acc.: 82.00%
# Time elapsed: 3.76 min
# Epoch: 011/100 | Batch 000/192 | Cost: 0.3496
# Epoch: 011/100 | Batch 120/192 | Cost: 0.3756
# Epoch: 011/100 Train Acc.: 88.14% | Validation Acc.: 80.90%
# Time elapsed: 4.13 min
# Epoch: 012/100 | Batch 000/192 | Cost: 0.4109
# Epoch: 012/100 | Batch 120/192 | Cost: 0.3989
# Epoch: 012/100 Train Acc.: 89.56% | Validation Acc.: 82.00%
# Time elapsed: 4.51 min
# Epoch: 013/100 | Batch 000/192 | Cost: 0.2813
# Epoch: 013/100 | Batch 120/192 | Cost: 0.2717
# Epoch: 013/100 Train Acc.: 90.20% | Validation Acc.: 83.30%
# Time elapsed: 4.89 min
# Epoch: 014/100 | Batch 000/192 | Cost: 0.2231
# Epoch: 014/100 | Batch 120/192 | Cost: 0.4180
# Epoch: 014/100 Train Acc.: 90.21% | Validation Acc.: 83.10%
# Time elapsed: 5.26 min
# Epoch: 015/100 | Batch 000/192 | Cost: 0.2375
# Epoch: 015/100 | Batch 120/192 | Cost: 0.3301
# Epoch: 015/100 Train Acc.: 90.75% | Validation Acc.: 81.80%
# Time elapsed: 5.64 min
# Epoch: 016/100 | Batch 000/192 | Cost: 0.2208
# Epoch: 016/100 | Batch 120/192 | Cost: 0.2961
# Epoch: 016/100 Train Acc.: 91.49% | Validation Acc.: 83.20%
# Time elapsed: 6.01 min
# Epoch: 017/100 | Batch 000/192 | Cost: 0.2650
# Epoch: 017/100 | Batch 120/192 | Cost: 0.2282
# Epoch: 017/100 Train Acc.: 91.97% | Validation Acc.: 83.30%
# Time elapsed: 6.39 min
# Epoch: 018/100 | Batch 000/192 | Cost: 0.1830
# Epoch: 018/100 | Batch 120/192 | Cost: 0.1703
# Epoch: 018/100 Train Acc.: 92.38% | Validation Acc.: 84.70%
# Time elapsed: 6.77 min
# Epoch: 019/100 | Batch 000/192 | Cost: 0.2295
# Epoch: 019/100 | Batch 120/192 | Cost: 0.2714
# Epoch: 019/100 Train Acc.: 92.10% | Validation Acc.: 83.20%
# Time elapsed: 7.14 min
# Epoch: 020/100 | Batch 000/192 | Cost: 0.2584
# Epoch: 020/100 | Batch 120/192 | Cost: 0.2876
# Epoch: 020/100 Train Acc.: 92.99% | Validation Acc.: 82.90%
# Time elapsed: 7.52 min
# Epoch: 021/100 | Batch 000/192 | Cost: 0.1877
# Epoch: 021/100 | Batch 120/192 | Cost: 0.2032
# Epoch: 021/100 Train Acc.: 93.37% | Validation Acc.: 82.70%
# Time elapsed: 7.90 min
# Epoch: 022/100 | Batch 000/192 | Cost: 0.1785
# Epoch: 022/100 | Batch 120/192 | Cost: 0.2257
# Epoch: 022/100 Train Acc.: 94.04% | Validation Acc.: 83.50%
# Time elapsed: 8.27 min
# Epoch: 023/100 | Batch 000/192 | Cost: 0.1931
# Epoch: 023/100 | Batch 120/192 | Cost: 0.2270
# Epoch: 023/100 Train Acc.: 94.31% | Validation Acc.: 84.20%
# Time elapsed: 8.65 min
# Epoch: 024/100 | Batch 000/192 | Cost: 0.1630
# Epoch: 024/100 | Batch 120/192 | Cost: 0.1969
# Epoch: 024/100 Train Acc.: 93.98% | Validation Acc.: 82.50%
# Time elapsed: 9.02 min
# Epoch: 025/100 | Batch 000/192 | Cost: 0.2496
# Epoch: 025/100 | Batch 120/192 | Cost: 0.1578
# Epoch: 025/100 Train Acc.: 94.81% | Validation Acc.: 84.20%
# Time elapsed: 9.40 min
# Epoch: 026/100 | Batch 000/192 | Cost: 0.1552
# Epoch: 026/100 | Batch 120/192 | Cost: 0.1710
# Epoch: 026/100 Train Acc.: 94.96% | Validation Acc.: 83.40%
# Time elapsed: 9.78 min
# Epoch: 027/100 | Batch 000/192 | Cost: 0.1364
# Epoch: 027/100 | Batch 120/192 | Cost: 0.1018
# Epoch: 027/100 Train Acc.: 94.76% | Validation Acc.: 83.20%
# Time elapsed: 10.15 min
# Epoch: 028/100 | Batch 000/192 | Cost: 0.1136
# Epoch: 028/100 | Batch 120/192 | Cost: 0.1027
# Epoch: 028/100 Train Acc.: 95.24% | Validation Acc.: 83.50%
# Time elapsed: 10.53 min
# Epoch: 029/100 | Batch 000/192 | Cost: 0.1118
# Epoch: 029/100 | Batch 120/192 | Cost: 0.1242
# Epoch: 029/100 Train Acc.: 95.55% | Validation Acc.: 84.20%
# Time elapsed: 10.91 min
# Epoch: 030/100 | Batch 000/192 | Cost: 0.1321
# Epoch: 030/100 | Batch 120/192 | Cost: 0.1282
# Epoch: 030/100 Train Acc.: 95.43% | Validation Acc.: 84.00%
# Time elapsed: 11.28 min
# Epoch: 031/100 | Batch 000/192 | Cost: 0.0839
# Epoch: 031/100 | Batch 120/192 | Cost: 0.1165
# Epoch: 031/100 Train Acc.: 95.97% | Validation Acc.: 84.00%
# Time elapsed: 11.66 min
# Epoch: 032/100 | Batch 000/192 | Cost: 0.1067
# Epoch: 032/100 | Batch 120/192 | Cost: 0.1083
# Epoch: 032/100 Train Acc.: 96.06% | Validation Acc.: 84.90%
# Time elapsed: 12.04 min
# Epoch: 033/100 | Batch 000/192 | Cost: 0.0838
# Epoch: 033/100 | Batch 120/192 | Cost: 0.1309
# Epoch: 033/100 Train Acc.: 95.99% | Validation Acc.: 81.90%
# Time elapsed: 12.41 min
# Epoch: 034/100 | Batch 000/192 | Cost: 0.0700
# Epoch: 034/100 | Batch 120/192 | Cost: 0.1079
# Epoch: 034/100 Train Acc.: 96.01% | Validation Acc.: 83.50%
# Time elapsed: 12.79 min
# Epoch: 035/100 | Batch 000/192 | Cost: 0.0975
# Epoch: 035/100 | Batch 120/192 | Cost: 0.1651
# Epoch: 035/100 Train Acc.: 95.94% | Validation Acc.: 84.20%
# Time elapsed: 13.16 min
# Epoch: 036/100 | Batch 000/192 | Cost: 0.0993
# Epoch: 036/100 | Batch 120/192 | Cost: 0.1237
# Epoch: 036/100 Train Acc.: 96.34% | Validation Acc.: 84.90%
# Time elapsed: 13.54 min
# Epoch: 037/100 | Batch 000/192 | Cost: 0.1356
# Epoch: 037/100 | Batch 120/192 | Cost: 0.1279
# Epoch: 037/100 Train Acc.: 96.38% | Validation Acc.: 82.70%
# Time elapsed: 13.92 min
# Epoch: 038/100 | Batch 000/192 | Cost: 0.0548
# Epoch: 038/100 | Batch 120/192 | Cost: 0.1137
# Epoch: 038/100 Train Acc.: 96.43% | Validation Acc.: 82.80%
# Time elapsed: 14.29 min
# Epoch: 039/100 | Batch 000/192 | Cost: 0.0665
# Epoch: 039/100 | Batch 120/192 | Cost: 0.1409
# Epoch: 039/100 Train Acc.: 96.01% | Validation Acc.: 83.30%
# Time elapsed: 14.67 min
# Epoch: 040/100 | Batch 000/192 | Cost: 0.0889
# Epoch: 040/100 | Batch 120/192 | Cost: 0.0697
# Epoch: 040/100 Train Acc.: 96.76% | Validation Acc.: 83.80%
# Time elapsed: 15.04 min
# Epoch: 041/100 | Batch 000/192 | Cost: 0.0562
# Epoch: 041/100 | Batch 120/192 | Cost: 0.1142
# Epoch: 041/100 Train Acc.: 96.75% | Validation Acc.: 84.40%
# Time elapsed: 15.42 min
# Epoch: 042/100 | Batch 000/192 | Cost: 0.0638
# Epoch: 042/100 | Batch 120/192 | Cost: 0.0776
# Epoch: 042/100 Train Acc.: 97.13% | Validation Acc.: 84.20%
# Time elapsed: 15.80 min
# Epoch: 043/100 | Batch 000/192 | Cost: 0.0589
# Epoch: 043/100 | Batch 120/192 | Cost: 0.1090
# Epoch: 043/100 Train Acc.: 96.94% | Validation Acc.: 83.00%
# Time elapsed: 16.17 min
# Epoch: 044/100 | Batch 000/192 | Cost: 0.0700
# Epoch: 044/100 | Batch 120/192 | Cost: 0.1100
# Epoch: 044/100 Train Acc.: 97.26% | Validation Acc.: 85.20%
# Time elapsed: 16.55 min
# Epoch: 045/100 | Batch 000/192 | Cost: 0.0802
# Epoch: 045/100 | Batch 120/192 | Cost: 0.1019
# Epoch: 045/100 Train Acc.: 97.20% | Validation Acc.: 84.00%
# Time elapsed: 16.93 min
# Epoch: 046/100 | Batch 000/192 | Cost: 0.0990
# Epoch: 046/100 | Batch 120/192 | Cost: 0.0756
# Epoch: 046/100 Train Acc.: 97.29% | Validation Acc.: 84.10%
# Time elapsed: 17.30 min
# Epoch: 047/100 | Batch 000/192 | Cost: 0.0468
# Epoch: 047/100 | Batch 120/192 | Cost: 0.1239
# Epoch: 047/100 Train Acc.: 97.35% | Validation Acc.: 83.80%
# Time elapsed: 17.68 min
# Epoch: 048/100 | Batch 000/192 | Cost: 0.0560
# Epoch: 048/100 | Batch 120/192 | Cost: 0.0911
# Epoch: 048/100 Train Acc.: 97.07% | Validation Acc.: 82.20%
# Time elapsed: 18.06 min
# Epoch: 049/100 | Batch 000/192 | Cost: 0.1096
# Epoch: 049/100 | Batch 120/192 | Cost: 0.0901
# Epoch: 049/100 Train Acc.: 97.28% | Validation Acc.: 83.70%
# Time elapsed: 18.43 min
# Epoch: 050/100 | Batch 000/192 | Cost: 0.0926
# Epoch: 050/100 | Batch 120/192 | Cost: 0.0841
# Epoch: 050/100 Train Acc.: 97.19% | Validation Acc.: 84.00%
# Time elapsed: 18.81 min
# Epoch: 051/100 | Batch 000/192 | Cost: 0.0588
# Epoch: 051/100 | Batch 120/192 | Cost: 0.0493
# Epoch: 051/100 Train Acc.: 97.56% | Validation Acc.: 84.50%
# Time elapsed: 19.19 min
# Epoch: 052/100 | Batch 000/192 | Cost: 0.0573
# Epoch: 052/100 | Batch 120/192 | Cost: 0.1091
# Epoch: 052/100 Train Acc.: 97.53% | Validation Acc.: 84.20%
# Time elapsed: 19.57 min
# Epoch: 053/100 | Batch 000/192 | Cost: 0.0695
# Epoch: 053/100 | Batch 120/192 | Cost: 0.0595
# Epoch: 053/100 Train Acc.: 97.08% | Validation Acc.: 83.70%
# Time elapsed: 19.94 min
# Epoch: 054/100 | Batch 000/192 | Cost: 0.1480
# Epoch: 054/100 | Batch 120/192 | Cost: 0.1024
# Epoch: 054/100 Train Acc.: 97.65% | Validation Acc.: 83.80%
# Time elapsed: 20.32 min
# Epoch: 055/100 | Batch 000/192 | Cost: 0.0420
# Epoch: 055/100 | Batch 120/192 | Cost: 0.0812
# Epoch: 055/100 Train Acc.: 97.57% | Validation Acc.: 84.00%
# Time elapsed: 20.69 min
# Epoch: 056/100 | Batch 000/192 | Cost: 0.0445
# Epoch: 056/100 | Batch 120/192 | Cost: 0.0516
# Epoch: 056/100 Train Acc.: 97.59% | Validation Acc.: 83.50%
# Time elapsed: 21.07 min
# Epoch: 057/100 | Batch 000/192 | Cost: 0.0628
# Epoch: 057/100 | Batch 120/192 | Cost: 0.1095
# Epoch: 057/100 Train Acc.: 97.60% | Validation Acc.: 84.00%
# Time elapsed: 21.45 min
# Epoch: 058/100 | Batch 000/192 | Cost: 0.0694
# Epoch: 058/100 | Batch 120/192 | Cost: 0.0868
# Epoch: 058/100 Train Acc.: 97.85% | Validation Acc.: 83.40%
# Time elapsed: 21.82 min
# Epoch: 059/100 | Batch 000/192 | Cost: 0.0832
# Epoch: 059/100 | Batch 120/192 | Cost: 0.0558
# Epoch: 059/100 Train Acc.: 97.92% | Validation Acc.: 84.10%
# Time elapsed: 22.20 min
# Epoch: 060/100 | Batch 000/192 | Cost: 0.0595
# Epoch: 060/100 | Batch 120/192 | Cost: 0.0880
# Epoch: 060/100 Train Acc.: 97.87% | Validation Acc.: 84.00%
# Time elapsed: 22.58 min
# Epoch: 061/100 | Batch 000/192 | Cost: 0.0673
# Epoch: 061/100 | Batch 120/192 | Cost: 0.0501
# Epoch: 061/100 Train Acc.: 97.90% | Validation Acc.: 85.70%
# Time elapsed: 22.95 min
# Epoch: 062/100 | Batch 000/192 | Cost: 0.0535
# Epoch: 062/100 | Batch 120/192 | Cost: 0.0594
# Epoch: 062/100 Train Acc.: 97.94% | Validation Acc.: 83.80%
# Time elapsed: 23.33 min
# Epoch: 063/100 | Batch 000/192 | Cost: 0.0856
# Epoch: 063/100 | Batch 120/192 | Cost: 0.0611
# Epoch: 063/100 Train Acc.: 97.99% | Validation Acc.: 85.10%
# Time elapsed: 23.71 min
# Epoch: 064/100 | Batch 000/192 | Cost: 0.0487
# Epoch: 064/100 | Batch 120/192 | Cost: 0.0648
# Epoch: 064/100 Train Acc.: 97.65% | Validation Acc.: 85.10%
# Time elapsed: 24.08 min
# Epoch: 065/100 | Batch 000/192 | Cost: 0.0463
# Epoch: 065/100 | Batch 120/192 | Cost: 0.0579
# Epoch: 065/100 Train Acc.: 97.83% | Validation Acc.: 85.80%
# Time elapsed: 24.46 min
# Epoch: 066/100 | Batch 000/192 | Cost: 0.0433
# Epoch: 066/100 | Batch 120/192 | Cost: 0.0814
# Epoch: 066/100 Train Acc.: 98.02% | Validation Acc.: 83.80%
# Time elapsed: 24.83 min
# Epoch: 067/100 | Batch 000/192 | Cost: 0.0697
# Epoch: 067/100 | Batch 120/192 | Cost: 0.0781
# Epoch: 067/100 Train Acc.: 97.66% | Validation Acc.: 84.00%
# Time elapsed: 25.21 min
# Epoch: 068/100 | Batch 000/192 | Cost: 0.0248
# Epoch: 068/100 | Batch 120/192 | Cost: 0.0526
# Epoch: 068/100 Train Acc.: 98.20% | Validation Acc.: 85.00%
# Time elapsed: 25.59 min
# Epoch: 069/100 | Batch 000/192 | Cost: 0.0519
# Epoch: 069/100 | Batch 120/192 | Cost: 0.0483
# Epoch: 069/100 Train Acc.: 98.05% | Validation Acc.: 83.50%
# Time elapsed: 25.96 min
# Epoch: 070/100 | Batch 000/192 | Cost: 0.0726
# Epoch: 070/100 | Batch 120/192 | Cost: 0.0529
# Epoch: 070/100 Train Acc.: 98.05% | Validation Acc.: 85.20%
# Time elapsed: 26.34 min
# Epoch: 071/100 | Batch 000/192 | Cost: 0.0451
# Epoch: 071/100 | Batch 120/192 | Cost: 0.0416
# Epoch: 071/100 Train Acc.: 98.09% | Validation Acc.: 85.20%
# Time elapsed: 26.71 min
# Epoch: 072/100 | Batch 000/192 | Cost: 0.0181
# Epoch: 072/100 | Batch 120/192 | Cost: 0.0855
# Epoch: 072/100 Train Acc.: 98.19% | Validation Acc.: 84.10%
# Time elapsed: 27.09 min
# Epoch: 073/100 | Batch 000/192 | Cost: 0.0574
# Epoch: 073/100 | Batch 120/192 | Cost: 0.0362
# Epoch: 073/100 Train Acc.: 98.11% | Validation Acc.: 85.70%
# Time elapsed: 27.47 min
# Epoch: 074/100 | Batch 000/192 | Cost: 0.0662
# Epoch: 074/100 | Batch 120/192 | Cost: 0.0349
# Epoch: 074/100 Train Acc.: 97.98% | Validation Acc.: 85.70%
# Time elapsed: 27.84 min
# Epoch: 075/100 | Batch 000/192 | Cost: 0.0219
# Epoch: 075/100 | Batch 120/192 | Cost: 0.0516
# Epoch: 075/100 Train Acc.: 98.06% | Validation Acc.: 85.00%
# Time elapsed: 28.22 min
# Epoch: 076/100 | Batch 000/192 | Cost: 0.0381
# Epoch: 076/100 | Batch 120/192 | Cost: 0.0571
# Epoch: 076/100 Train Acc.: 98.09% | Validation Acc.: 85.30%
# Time elapsed: 28.59 min
# Epoch: 077/100 | Batch 000/192 | Cost: 0.0538
# Epoch: 077/100 | Batch 120/192 | Cost: 0.0440
# Epoch: 077/100 Train Acc.: 98.46% | Validation Acc.: 84.70%
# Time elapsed: 28.97 min
# Epoch: 078/100 | Batch 000/192 | Cost: 0.0538
# Epoch: 078/100 | Batch 120/192 | Cost: 0.0403
# Epoch: 078/100 Train Acc.: 98.10% | Validation Acc.: 83.70%
# Time elapsed: 29.35 min
# Epoch: 079/100 | Batch 000/192 | Cost: 0.0591
# Epoch: 079/100 | Batch 120/192 | Cost: 0.0324
# Epoch: 079/100 Train Acc.: 98.19% | Validation Acc.: 84.70%
# Time elapsed: 29.72 min
# Epoch: 080/100 | Batch 000/192 | Cost: 0.0747
# Epoch: 080/100 | Batch 120/192 | Cost: 0.0838
# Epoch: 080/100 Train Acc.: 98.30% | Validation Acc.: 85.80%
# Time elapsed: 30.10 min
# Epoch: 081/100 | Batch 000/192 | Cost: 0.0705
# Epoch: 081/100 | Batch 120/192 | Cost: 0.0629
# Epoch: 081/100 Train Acc.: 98.36% | Validation Acc.: 83.60%
# Time elapsed: 30.47 min
# Epoch: 082/100 | Batch 000/192 | Cost: 0.0279
# Epoch: 082/100 | Batch 120/192 | Cost: 0.0355
# Epoch: 082/100 Train Acc.: 98.29% | Validation Acc.: 85.30%
# Time elapsed: 30.85 min
# Epoch: 083/100 | Batch 000/192 | Cost: 0.0322
# Epoch: 083/100 | Batch 120/192 | Cost: 0.0373
# Epoch: 083/100 Train Acc.: 98.32% | Validation Acc.: 84.30%
# Time elapsed: 31.22 min
# Epoch: 084/100 | Batch 000/192 | Cost: 0.0402
# Epoch: 084/100 | Batch 120/192 | Cost: 0.0412
# Epoch: 084/100 Train Acc.: 98.23% | Validation Acc.: 84.20%
# Time elapsed: 31.60 min
# Epoch: 085/100 | Batch 000/192 | Cost: 0.0385
# Epoch: 085/100 | Batch 120/192 | Cost: 0.0384
# Epoch: 085/100 Train Acc.: 98.09% | Validation Acc.: 86.10%
# Time elapsed: 31.98 min
# Epoch: 086/100 | Batch 000/192 | Cost: 0.0518
# Epoch: 086/100 | Batch 120/192 | Cost: 0.0548
# Epoch: 086/100 Train Acc.: 98.21% | Validation Acc.: 84.50%
# Time elapsed: 32.35 min
# Epoch: 087/100 | Batch 000/192 | Cost: 0.0672
# Epoch: 087/100 | Batch 120/192 | Cost: 0.0406
# Epoch: 087/100 Train Acc.: 98.39% | Validation Acc.: 85.20%
# Time elapsed: 32.73 min
# Epoch: 088/100 | Batch 000/192 | Cost: 0.0613
# Epoch: 088/100 | Batch 120/192 | Cost: 0.0587
# Epoch: 088/100 Train Acc.: 98.63% | Validation Acc.: 86.40%
# Time elapsed: 33.10 min
# Epoch: 089/100 | Batch 000/192 | Cost: 0.0359
# Epoch: 089/100 | Batch 120/192 | Cost: 0.0533
# Epoch: 089/100 Train Acc.: 98.32% | Validation Acc.: 85.60%
# Time elapsed: 33.48 min
# Epoch: 090/100 | Batch 000/192 | Cost: 0.0572
# Epoch: 090/100 | Batch 120/192 | Cost: 0.0624
# Epoch: 090/100 Train Acc.: 98.29% | Validation Acc.: 84.80%
# Time elapsed: 33.86 min
# Epoch: 091/100 | Batch 000/192 | Cost: 0.0272
# Epoch: 091/100 | Batch 120/192 | Cost: 0.0623
# Epoch: 091/100 Train Acc.: 98.40% | Validation Acc.: 84.50%
# Time elapsed: 34.23 min
# Epoch: 092/100 | Batch 000/192 | Cost: 0.0267
# Epoch: 092/100 | Batch 120/192 | Cost: 0.0586
# Epoch: 092/100 Train Acc.: 98.29% | Validation Acc.: 83.80%
# Time elapsed: 34.61 min
# Epoch: 093/100 | Batch 000/192 | Cost: 0.0266
# Epoch: 093/100 | Batch 120/192 | Cost: 0.0795
# Epoch: 093/100 Train Acc.: 98.41% | Validation Acc.: 84.60%
# Time elapsed: 34.99 min
# Epoch: 094/100 | Batch 000/192 | Cost: 0.0676
# Epoch: 094/100 | Batch 120/192 | Cost: 0.0483
# Epoch: 094/100 Train Acc.: 98.67% | Validation Acc.: 85.30%
# Time elapsed: 35.36 min
# Epoch: 095/100 | Batch 000/192 | Cost: 0.0551
# Epoch: 095/100 | Batch 120/192 | Cost: 0.0178
# Epoch: 095/100 Train Acc.: 98.71% | Validation Acc.: 84.80%
# Time elapsed: 35.74 min
# Epoch: 096/100 | Batch 000/192 | Cost: 0.0547
# Epoch: 096/100 | Batch 120/192 | Cost: 0.0452
# Epoch: 096/100 Train Acc.: 98.45% | Validation Acc.: 86.20%
# Time elapsed: 36.11 min
# Epoch: 097/100 | Batch 000/192 | Cost: 0.0397
# Epoch: 097/100 | Batch 120/192 | Cost: 0.0706
# Epoch: 097/100 Train Acc.: 98.44% | Validation Acc.: 85.80%
# Time elapsed: 36.49 min
# Epoch: 098/100 | Batch 000/192 | Cost: 0.0432
# Epoch: 098/100 | Batch 120/192 | Cost: 0.0815
# Epoch: 098/100 Train Acc.: 98.45% | Validation Acc.: 85.10%
# Time elapsed: 36.86 min
# Epoch: 099/100 | Batch 000/192 | Cost: 0.0524
# Epoch: 099/100 | Batch 120/192 | Cost: 0.0582
# Epoch: 099/100 Train Acc.: 98.36% | Validation Acc.: 84.90%
# Time elapsed: 37.24 min
# Epoch: 100/100 | Batch 000/192 | Cost: 0.0299
# Epoch: 100/100 | Batch 120/192 | Cost: 0.0326
# Epoch: 100/100 Train Acc.: 98.53% | Validation Acc.: 85.20%
# Time elapsed: 37.62 min
# Total Training Time: 37.62 min
