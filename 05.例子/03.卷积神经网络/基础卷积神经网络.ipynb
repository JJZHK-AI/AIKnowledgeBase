# %% [markdown]
# 基础卷积神经网络
# ===

# %%
# %load_ext watermark
# %watermark -a 'Sebastian Raschka' -v -p torch
# Out:
# Sebastian Raschka
#
# CPython 3.6.9
# IPython 7.9.0
#
# torch 1.1.0

# %%
import time
import numpy as np
import torch
import torch.nn.functional as F
from torchvision import datasets
from torchvision import transforms
from torch.utils.data import DataLoader

if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True

# %% [markdown]
# # 1.数据导入

# %%
# Device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Hyperparameters
random_seed = 1
learning_rate = 0.05
num_epochs = 10
batch_size = 128

# Architecture
num_classes = 10

train_dataset = datasets.MNIST(root='/data/input/', 
                               train=True, 
                               transform=transforms.ToTensor(),
                               download=True)

test_dataset = datasets.MNIST(root='/data/input/', 
                              train=False, 
                              transform=transforms.ToTensor())


train_loader = DataLoader(dataset=train_dataset, 
                          batch_size=batch_size, 
                          shuffle=True)

test_loader = DataLoader(dataset=test_dataset, 
                         batch_size=batch_size, 
                         shuffle=False)

# Checking the dataset
for images, labels in train_loader:  
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    break
# Out:
# Image batch dimensions: torch.Size([128, 1, 28, 28])
# Image label dimensions: torch.Size([128])

# %% [markdown]
# # 2.模型

# %%
class ConvNet(torch.nn.Module):

    def __init__(self, num_classes):
        super(ConvNet, self).__init__()
        
        # calculate same padding:
        # (w - k + 2*p)/s + 1 = o
        # => p = (s(o-1) - w + k)/2
        
        # 28x28x1 => 28x28x8
        self.conv_1 = torch.nn.Conv2d(in_channels=1,
                                      out_channels=8,
                                      kernel_size=(3, 3),
                                      stride=(1, 1),
                                      padding=1) # (1(28-1) - 28 + 3) / 2 = 1
        # 28x28x8 => 14x14x8
        self.pool_1 = torch.nn.MaxPool2d(kernel_size=(2, 2),
                                         stride=(2, 2),
                                         padding=0) # (2(14-1) - 28 + 2) = 0                                       
        # 14x14x8 => 14x14x16
        self.conv_2 = torch.nn.Conv2d(in_channels=8,
                                      out_channels=16,
                                      kernel_size=(3, 3),
                                      stride=(1, 1),
                                      padding=1) # (1(14-1) - 14 + 3) / 2 = 1                 
        # 14x14x16 => 7x7x16                             
        self.pool_2 = torch.nn.MaxPool2d(kernel_size=(2, 2),
                                         stride=(2, 2),
                                         padding=0) # (2(7-1) - 14 + 2) = 0

        self.linear_1 = torch.nn.Linear(7*7*16, num_classes)

        # optionally initialize weights from Gaussian;
        # Guassian weight init is not recommended and only for demonstration purposes
        for m in self.modules():
            if isinstance(m, torch.nn.Conv2d) or isinstance(m, torch.nn.Linear):
                m.weight.data.normal_(0.0, 0.01)
                m.bias.data.zero_()
                if m.bias is not None:
                    m.bias.detach().zero_()
        
        
    def forward(self, x):
        out = self.conv_1(x)
        out = F.relu(out)
        out = self.pool_1(out)

        out = self.conv_2(out)
        out = F.relu(out)
        out = self.pool_2(out)
        
        logits = self.linear_1(out.view(-1, 7*7*16))
        probas = F.softmax(logits, dim=1)
        return logits, probas

    
torch.manual_seed(random_seed)
model = ConvNet(num_classes=num_classes)

model = model.to(device)

optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %% [markdown]
# # 3.训练

# %%
def compute_accuracy(model, data_loader):
    correct_pred, num_examples = 0, 0
    for features, targets in data_loader:
        features = features.to(device)
        targets = targets.to(device)
        logits, probas = model(features)
        _, predicted_labels = torch.max(probas, 1)
        num_examples += targets.size(0)
        correct_pred += (predicted_labels == targets).sum()
    return correct_pred.float()/num_examples * 100
    

start_time = time.time()    
for epoch in range(num_epochs):
    model = model.train()
    for batch_idx, (features, targets) in enumerate(train_loader):
        
        features = features.to(device)
        targets = targets.to(device)

        ### FORWARD AND BACK PROP
        logits, probas = model(features)
        cost = F.cross_entropy(logits, targets)
        optimizer.zero_grad()
        
        cost.backward()
        
        ### UPDATE MODEL PARAMETERS
        optimizer.step()
        
        ### LOGGING
        if not batch_idx % 50:
            print ('Epoch: %03d/%03d | Batch %03d/%03d | Cost: %.4f' 
                   %(epoch+1, num_epochs, batch_idx, 
                     len(train_loader), cost))
    
    model = model.eval()
    print('Epoch: %03d/%03d training accuracy: %.2f%%' % (
          epoch+1, num_epochs, 
          compute_accuracy(model, train_loader)))

    print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))
    
print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))
# Out:
# Epoch: 001/010 | Batch 000/469 | Cost: 2.3026
# Epoch: 001/010 | Batch 050/469 | Cost: 2.3036
# Epoch: 001/010 | Batch 100/469 | Cost: 2.3001
# Epoch: 001/010 | Batch 150/469 | Cost: 2.3050
# Epoch: 001/010 | Batch 200/469 | Cost: 2.2984
# Epoch: 001/010 | Batch 250/469 | Cost: 2.2986
# Epoch: 001/010 | Batch 300/469 | Cost: 2.2983
# Epoch: 001/010 | Batch 350/469 | Cost: 2.2941
# Epoch: 001/010 | Batch 400/469 | Cost: 2.2962
# Epoch: 001/010 | Batch 450/469 | Cost: 2.2267
# Epoch: 001/010 training accuracy: 65.36%
# Time elapsed: 0.21 min
# Epoch: 002/010 | Batch 000/469 | Cost: 1.8999
# Epoch: 002/010 | Batch 050/469 | Cost: 0.5965
# Epoch: 002/010 | Batch 100/469 | Cost: 0.6162
# Epoch: 002/010 | Batch 150/469 | Cost: 0.4805
# Epoch: 002/010 | Batch 200/469 | Cost: 0.4524
# Epoch: 002/010 | Batch 250/469 | Cost: 0.3553
# Epoch: 002/010 | Batch 300/469 | Cost: 0.3169
# Epoch: 002/010 | Batch 350/469 | Cost: 0.2240
# Epoch: 002/010 | Batch 400/469 | Cost: 0.2259
# Epoch: 002/010 | Batch 450/469 | Cost: 0.3054
# Epoch: 002/010 training accuracy: 93.11%
# Time elapsed: 0.41 min
# Epoch: 003/010 | Batch 000/469 | Cost: 0.3312
# Epoch: 003/010 | Batch 050/469 | Cost: 0.1041
# Epoch: 003/010 | Batch 100/469 | Cost: 0.1328
# Epoch: 003/010 | Batch 150/469 | Cost: 0.2801
# Epoch: 003/010 | Batch 200/469 | Cost: 0.0974
# Epoch: 003/010 | Batch 250/469 | Cost: 0.1838
# Epoch: 003/010 | Batch 300/469 | Cost: 0.1773
# Epoch: 003/010 | Batch 350/469 | Cost: 0.1141
# Epoch: 003/010 | Batch 400/469 | Cost: 0.1752
# Epoch: 003/010 | Batch 450/469 | Cost: 0.1543
# Epoch: 003/010 training accuracy: 95.68%
# Time elapsed: 0.63 min
# Epoch: 004/010 | Batch 000/469 | Cost: 0.1056
# Epoch: 004/010 | Batch 050/469 | Cost: 0.1034
# Epoch: 004/010 | Batch 100/469 | Cost: 0.1850
# Epoch: 004/010 | Batch 150/469 | Cost: 0.1607
# Epoch: 004/010 | Batch 200/469 | Cost: 0.1462
# Epoch: 004/010 | Batch 250/469 | Cost: 0.1915
# Epoch: 004/010 | Batch 300/469 | Cost: 0.1292
# Epoch: 004/010 | Batch 350/469 | Cost: 0.1517
# Epoch: 004/010 | Batch 400/469 | Cost: 0.1717
# Epoch: 004/010 | Batch 450/469 | Cost: 0.0790
# Epoch: 004/010 training accuracy: 96.47%
# Time elapsed: 0.83 min
# Epoch: 005/010 | Batch 000/469 | Cost: 0.0904
# Epoch: 005/010 | Batch 050/469 | Cost: 0.1618
# Epoch: 005/010 | Batch 100/469 | Cost: 0.1938
# Epoch: 005/010 | Batch 150/469 | Cost: 0.1869
# Epoch: 005/010 | Batch 200/469 | Cost: 0.0749
# Epoch: 005/010 | Batch 250/469 | Cost: 0.1057
# Epoch: 005/010 | Batch 300/469 | Cost: 0.0997
# Epoch: 005/010 | Batch 350/469 | Cost: 0.0933
# Epoch: 005/010 | Batch 400/469 | Cost: 0.0573
# Epoch: 005/010 | Batch 450/469 | Cost: 0.1160
# Epoch: 005/010 training accuracy: 96.97%
# Time elapsed: 1.03 min
# Epoch: 006/010 | Batch 000/469 | Cost: 0.1326
# Epoch: 006/010 | Batch 050/469 | Cost: 0.1547
# Epoch: 006/010 | Batch 100/469 | Cost: 0.0786
# Epoch: 006/010 | Batch 150/469 | Cost: 0.0892
# Epoch: 006/010 | Batch 200/469 | Cost: 0.0989
# Epoch: 006/010 | Batch 250/469 | Cost: 0.0969
# Epoch: 006/010 | Batch 300/469 | Cost: 0.0480
# Epoch: 006/010 | Batch 350/469 | Cost: 0.0718
# Epoch: 006/010 | Batch 400/469 | Cost: 0.1093
# Epoch: 006/010 | Batch 450/469 | Cost: 0.0327
# Epoch: 006/010 training accuracy: 97.61%
# Time elapsed: 1.23 min
# Epoch: 007/010 | Batch 000/469 | Cost: 0.0661
# Epoch: 007/010 | Batch 050/469 | Cost: 0.0852
# Epoch: 007/010 | Batch 100/469 | Cost: 0.0427
# Epoch: 007/010 | Batch 150/469 | Cost: 0.0388
# Epoch: 007/010 | Batch 200/469 | Cost: 0.0606
# Epoch: 007/010 | Batch 250/469 | Cost: 0.0491
# Epoch: 007/010 | Batch 300/469 | Cost: 0.1279
# Epoch: 007/010 | Batch 350/469 | Cost: 0.0308
# Epoch: 007/010 | Batch 400/469 | Cost: 0.0358
# Epoch: 007/010 | Batch 450/469 | Cost: 0.0139
# Epoch: 007/010 training accuracy: 97.65%
# Time elapsed: 1.44 min
# Epoch: 008/010 | Batch 000/469 | Cost: 0.0943
# Epoch: 008/010 | Batch 050/469 | Cost: 0.1474
# Epoch: 008/010 | Batch 100/469 | Cost: 0.0766
# Epoch: 008/010 | Batch 150/469 | Cost: 0.0714
# Epoch: 008/010 | Batch 200/469 | Cost: 0.1273
# Epoch: 008/010 | Batch 250/469 | Cost: 0.0437
# Epoch: 008/010 | Batch 300/469 | Cost: 0.0529
# Epoch: 008/010 | Batch 350/469 | Cost: 0.1718
# Epoch: 008/010 | Batch 400/469 | Cost: 0.0676
# Epoch: 008/010 | Batch 450/469 | Cost: 0.0767
# Epoch: 008/010 training accuracy: 96.70%
# Time elapsed: 1.66 min
# Epoch: 009/010 | Batch 000/469 | Cost: 0.0967
# Epoch: 009/010 | Batch 050/469 | Cost: 0.0405
# Epoch: 009/010 | Batch 100/469 | Cost: 0.1053
# Epoch: 009/010 | Batch 150/469 | Cost: 0.0516
# Epoch: 009/010 | Batch 200/469 | Cost: 0.0804
# Epoch: 009/010 | Batch 250/469 | Cost: 0.0813
# Epoch: 009/010 | Batch 300/469 | Cost: 0.0417
# Epoch: 009/010 | Batch 350/469 | Cost: 0.0745
# Epoch: 009/010 | Batch 400/469 | Cost: 0.0461
# Epoch: 009/010 | Batch 450/469 | Cost: 0.0657
# Epoch: 009/010 training accuracy: 97.89%
# Time elapsed: 1.87 min
# Epoch: 010/010 | Batch 000/469 | Cost: 0.0252
# Epoch: 010/010 | Batch 050/469 | Cost: 0.0359
# Epoch: 010/010 | Batch 100/469 | Cost: 0.1483
# Epoch: 010/010 | Batch 150/469 | Cost: 0.0169
# Epoch: 010/010 | Batch 200/469 | Cost: 0.0494
# Epoch: 010/010 | Batch 250/469 | Cost: 0.0488
# Epoch: 010/010 | Batch 300/469 | Cost: 0.1361
# Epoch: 010/010 | Batch 350/469 | Cost: 0.0812
# Epoch: 010/010 | Batch 400/469 | Cost: 0.0560
# Epoch: 010/010 | Batch 450/469 | Cost: 0.0424
# Epoch: 010/010 training accuracy: 97.98%
# Time elapsed: 2.07 min
# Total Training Time: 2.07 min

# %% [markdown]
# # 4.评估

# %%
with torch.set_grad_enabled(False): # save memory during inference
    print('Test accuracy: %.2f%%' % (compute_accuracy(model, test_loader)))
# Out:
# Test accuracy: 97.97%
