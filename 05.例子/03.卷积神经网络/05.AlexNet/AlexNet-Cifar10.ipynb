# %% [markdown]
# 使用AlexNet网络对Cifar10进行分类
# ===

# %%
import os
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torch.utils.data.dataset import Subset

from torchvision import datasets
from torchvision import transforms

import matplotlib.pyplot as plt
from PIL import Image


if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True

# %% [markdown]
# # 1.全局设置

# %%
RANDOM_SEED = 1
LEARNING_RATE = 0.0001
BATCH_SIZE = 256
NUM_EPOCHS = 40

# Architecture
NUM_CLASSES = 10

# Other
DEVICE = "cuda:0"

# %% [markdown]
# # 2.导入数据

# %%
train_indices = torch.arange(0, 48000)
valid_indices = torch.arange(48000, 50000)


train_transform = transforms.Compose([transforms.Resize((70, 70)),
                                      transforms.RandomCrop((64, 64)),
                                      transforms.ToTensor()])

test_transform = transforms.Compose([transforms.Resize((70, 70)),
                                     transforms.CenterCrop((64, 64)),
                                     transforms.ToTensor()])

train_and_valid = datasets.CIFAR10(root='/data/input/', 
                                   train=True, 
                                   transform=train_transform,
                                   download=False)

train_dataset = Subset(train_and_valid, train_indices)
valid_dataset = Subset(train_and_valid, valid_indices)
test_dataset = datasets.CIFAR10(root='/data/input/', 
                                train=False, 
                                transform=test_transform,
                                download=False)




train_loader = DataLoader(dataset=train_dataset, 
                          batch_size=BATCH_SIZE,
                          num_workers=4,
                          shuffle=True)

valid_loader = DataLoader(dataset=valid_dataset, 
                          batch_size=BATCH_SIZE,
                          num_workers=4,
                          shuffle=False)

test_loader = DataLoader(dataset=test_dataset, 
                         batch_size=BATCH_SIZE,
                         num_workers=4,
                         shuffle=False)

# %%
# Checking the dataset
print('Training Set:\n')
for images, labels in train_loader:  
    print('Image batch dimensions:', images.size())
    print('Image label dimensions:', labels.size())
    break
    
# Checking the dataset
print('\nValidation Set:')
for images, labels in valid_loader:  
    print('Image batch dimensions:', images.size())
    print('Image label dimensions:', labels.size())
    break

# Checking the dataset
print('\nTesting Set:')
for images, labels in train_loader:  
    print('Image batch dimensions:', images.size())
    print('Image label dimensions:', labels.size())
    break
# Out:
# Training Set:
#
# Image batch dimensions: torch.Size([256, 3, 64, 64])
# Image label dimensions: torch.Size([256])
#
# Validation Set:
# Image batch dimensions: torch.Size([256, 3, 64, 64])
# Image label dimensions: torch.Size([256])
#
# Testing Set:
# Image batch dimensions: torch.Size([256, 3, 64, 64])
# Image label dimensions: torch.Size([256])

# %% [markdown]
# # 3.模型

# %%
class AlexNet(nn.Module):

    def __init__(self, num_classes):
        super(AlexNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.avgpool = nn.AdaptiveAvgPool2d((6, 6))
        self.classifier = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(256 * 6 * 6, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Linear(4096, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = x.view(x.size(0), 256 * 6 * 6)
        logits = self.classifier(x)
        probas = F.softmax(logits, dim=1)
        return logits, probas

model = AlexNet(NUM_CLASSES)
model.to(DEVICE)

optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %% [markdown]
# # 4.训练

# %%
def compute_acc(model, data_loader, device):
    correct_pred, num_examples = 0, 0
    model.eval()
    for i, (features, targets) in enumerate(data_loader):
            
        features = features.to(device)
        targets = targets.to(device)

        logits, probas = model(features)
        _, predicted_labels = torch.max(probas, 1)
        num_examples += targets.size(0)
        assert predicted_labels.size() == targets.size()
        correct_pred += (predicted_labels == targets).sum()
    return correct_pred.float()/num_examples * 100
    

start_time = time.time()

cost_list = []
train_acc_list, valid_acc_list = [], []


for epoch in range(NUM_EPOCHS):
    
    model.train()
    for batch_idx, (features, targets) in enumerate(train_loader):
        
        features = features.to(DEVICE)
        targets = targets.to(DEVICE)
            
        ### FORWARD AND BACK PROP
        logits, probas = model(features)
        cost = F.cross_entropy(logits, targets)
        optimizer.zero_grad()
        
        cost.backward()
        
        ### UPDATE MODEL PARAMETERS
        optimizer.step()
        
        #################################################
        ### CODE ONLY FOR LOGGING BEYOND THIS POINT
        ################################################
        cost_list.append(cost.item())
        if not batch_idx % 150:
            print (f'Epoch: {epoch+1:03d}/{NUM_EPOCHS:03d} | '
                   f'Batch {batch_idx:03d}/{len(train_loader):03d} |' 
                   f' Cost: {cost:.4f}')

        

    model.eval()
    with torch.set_grad_enabled(False): # save memory during inference
        
        train_acc = compute_acc(model, train_loader, device=DEVICE)
        valid_acc = compute_acc(model, valid_loader, device=DEVICE)
        
        print(f'Epoch: {epoch+1:03d}/{NUM_EPOCHS:03d}\n'
              f'Train ACC: {train_acc:.2f} | Validation ACC: {valid_acc:.2f}')
        
        train_acc_list.append(train_acc)
        valid_acc_list.append(valid_acc)
        
    elapsed = (time.time() - start_time)/60
    print(f'Time elapsed: {elapsed:.2f} min')
  
elapsed = (time.time() - start_time)/60
print(f'Total Training Time: {elapsed:.2f} min')
# Out:
# Epoch: 001/040 | Batch 000/188 | Cost: 2.3027
# Epoch: 001/040 | Batch 150/188 | Cost: 1.8155
# Epoch: 001/040
# Train ACC: 34.25 | Validation ACC: 34.50
# Time elapsed: 0.46 min
# Epoch: 002/040 | Batch 000/188 | Cost: 1.7891
# Epoch: 002/040 | Batch 150/188 | Cost: 1.4934
# Epoch: 002/040
# Train ACC: 46.66 | Validation ACC: 47.25
# Time elapsed: 0.81 min
# Epoch: 003/040 | Batch 000/188 | Cost: 1.3608
# Epoch: 003/040 | Batch 150/188 | Cost: 1.3044
# Epoch: 003/040
# Train ACC: 53.04 | Validation ACC: 53.15
# Time elapsed: 1.15 min
# Epoch: 004/040 | Batch 000/188 | Cost: 1.2723
# Epoch: 004/040 | Batch 150/188 | Cost: 1.3227
# Epoch: 004/040
# Train ACC: 54.43 | Validation ACC: 53.15
# Time elapsed: 1.49 min
# Epoch: 005/040 | Batch 000/188 | Cost: 1.2138
# Epoch: 005/040 | Batch 150/188 | Cost: 1.2562
# Epoch: 005/040
# Train ACC: 60.52 | Validation ACC: 60.30
# Time elapsed: 1.83 min
# Epoch: 006/040 | Batch 000/188 | Cost: 1.0441
# Epoch: 006/040 | Batch 150/188 | Cost: 1.1029
# Epoch: 006/040
# Train ACC: 63.89 | Validation ACC: 62.00
# Time elapsed: 2.17 min
# Epoch: 007/040 | Batch 000/188 | Cost: 0.9886
# Epoch: 007/040 | Batch 150/188 | Cost: 1.0430
# Epoch: 007/040
# Train ACC: 66.11 | Validation ACC: 64.35
# Time elapsed: 2.51 min
# Epoch: 008/040 | Batch 000/188 | Cost: 0.9401
# Epoch: 008/040 | Batch 150/188 | Cost: 0.8979
# Epoch: 008/040
# Train ACC: 65.47 | Validation ACC: 62.80
# Time elapsed: 2.85 min
# Epoch: 009/040 | Batch 000/188 | Cost: 0.9839
# Epoch: 009/040 | Batch 150/188 | Cost: 0.8038
# Epoch: 009/040
# Train ACC: 71.19 | Validation ACC: 67.10
# Time elapsed: 3.19 min
# Epoch: 010/040 | Batch 000/188 | Cost: 0.9137
# Epoch: 010/040 | Batch 150/188 | Cost: 0.9427
# Epoch: 010/040
# Train ACC: 72.27 | Validation ACC: 68.25
# Time elapsed: 3.54 min
# Epoch: 011/040 | Batch 000/188 | Cost: 0.7433
# Epoch: 011/040 | Batch 150/188 | Cost: 0.8025
# Epoch: 011/040
# Train ACC: 75.09 | Validation ACC: 69.35
# Time elapsed: 3.89 min
# Epoch: 012/040 | Batch 000/188 | Cost: 0.6252
# Epoch: 012/040 | Batch 150/188 | Cost: 0.7853
# Epoch: 012/040
# Train ACC: 74.45 | Validation ACC: 67.90
# Time elapsed: 4.23 min
# Epoch: 013/040 | Batch 000/188 | Cost: 0.7758
# Epoch: 013/040 | Batch 150/188 | Cost: 0.6657
# Epoch: 013/040
# Train ACC: 76.14 | Validation ACC: 68.40
# Time elapsed: 4.58 min
# Epoch: 014/040 | Batch 000/188 | Cost: 0.6297
# Epoch: 014/040 | Batch 150/188 | Cost: 0.7848
# Epoch: 014/040
# Train ACC: 79.29 | Validation ACC: 70.25
# Time elapsed: 4.92 min
# Epoch: 015/040 | Batch 000/188 | Cost: 0.5928
# Epoch: 015/040 | Batch 150/188 | Cost: 0.6893
# Epoch: 015/040
# Train ACC: 79.56 | Validation ACC: 72.05
# Time elapsed: 5.26 min
# Epoch: 016/040 | Batch 000/188 | Cost: 0.6226
# Epoch: 016/040 | Batch 150/188 | Cost: 0.5692
# Epoch: 016/040
# Train ACC: 82.62 | Validation ACC: 71.25
# Time elapsed: 5.60 min
# Epoch: 017/040 | Batch 000/188 | Cost: 0.5420
# Epoch: 017/040 | Batch 150/188 | Cost: 0.4907
# Epoch: 017/040
# Train ACC: 83.22 | Validation ACC: 72.00
# Time elapsed: 5.94 min
# Epoch: 018/040 | Batch 000/188 | Cost: 0.4964
# Epoch: 018/040 | Batch 150/188 | Cost: 0.5325
# Epoch: 018/040
# Train ACC: 84.10 | Validation ACC: 72.10
# Time elapsed: 6.28 min
# Epoch: 019/040 | Batch 000/188 | Cost: 0.5148
# Epoch: 019/040 | Batch 150/188 | Cost: 0.5062
# Epoch: 019/040
# Train ACC: 84.44 | Validation ACC: 71.60
# Time elapsed: 6.63 min
# Epoch: 020/040 | Batch 000/188 | Cost: 0.4335
# Epoch: 020/040 | Batch 150/188 | Cost: 0.4815
# Epoch: 020/040
# Train ACC: 84.09 | Validation ACC: 70.25
# Time elapsed: 6.96 min
# Epoch: 021/040 | Batch 000/188 | Cost: 0.3618
# Epoch: 021/040 | Batch 150/188 | Cost: 0.3762
# Epoch: 021/040
# Train ACC: 87.37 | Validation ACC: 71.85
# Time elapsed: 7.31 min
# Epoch: 022/040 | Batch 000/188 | Cost: 0.5128
# Epoch: 022/040 | Batch 150/188 | Cost: 0.4670
# Epoch: 022/040
# Train ACC: 88.40 | Validation ACC: 72.90
# Time elapsed: 7.64 min
# Epoch: 023/040 | Batch 000/188 | Cost: 0.3464
# Epoch: 023/040 | Batch 150/188 | Cost: 0.4197
# Epoch: 023/040
# Train ACC: 90.12 | Validation ACC: 72.80
# Time elapsed: 7.98 min
# Epoch: 024/040 | Batch 000/188 | Cost: 0.2881
# Epoch: 024/040 | Batch 150/188 | Cost: 0.3464
# Epoch: 024/040
# Train ACC: 90.73 | Validation ACC: 73.30
# Time elapsed: 8.32 min
# Epoch: 025/040 | Batch 000/188 | Cost: 0.2240
# Epoch: 025/040 | Batch 150/188 | Cost: 0.2440
# Epoch: 025/040
# Train ACC: 91.64 | Validation ACC: 73.55
# Time elapsed: 8.65 min
# Epoch: 026/040 | Batch 000/188 | Cost: 0.3076
# Epoch: 026/040 | Batch 150/188 | Cost: 0.2946
# Epoch: 026/040
# Train ACC: 91.86 | Validation ACC: 72.05
# Time elapsed: 8.98 min
# Epoch: 027/040 | Batch 000/188 | Cost: 0.2481
# Epoch: 027/040 | Batch 150/188 | Cost: 0.2663
# Epoch: 027/040
# Train ACC: 92.81 | Validation ACC: 71.30
# Time elapsed: 9.32 min
# Epoch: 028/040 | Batch 000/188 | Cost: 0.2534
# Epoch: 028/040 | Batch 150/188 | Cost: 0.2571
# Epoch: 028/040
# Train ACC: 93.31 | Validation ACC: 71.10
# Time elapsed: 9.65 min
# Epoch: 029/040 | Batch 000/188 | Cost: 0.2388
# Epoch: 029/040 | Batch 150/188 | Cost: 0.3465
# Epoch: 029/040
# Train ACC: 93.05 | Validation ACC: 72.35
# Time elapsed: 9.98 min
# Epoch: 030/040 | Batch 000/188 | Cost: 0.2039
# Epoch: 030/040 | Batch 150/188 | Cost: 0.2633
# Epoch: 030/040
# Train ACC: 94.00 | Validation ACC: 71.90
# Time elapsed: 10.32 min
# Epoch: 031/040 | Batch 000/188 | Cost: 0.1373
# Epoch: 031/040 | Batch 150/188 | Cost: 0.1487
# Epoch: 031/040
# Train ACC: 93.97 | Validation ACC: 72.35
# Time elapsed: 10.65 min
# Epoch: 032/040 | Batch 000/188 | Cost: 0.1806
# Epoch: 032/040 | Batch 150/188 | Cost: 0.1788
# Epoch: 032/040
# Train ACC: 95.49 | Validation ACC: 73.85
# Time elapsed: 10.98 min
# Epoch: 033/040 | Batch 000/188 | Cost: 0.1711
# Epoch: 033/040 | Batch 150/188 | Cost: 0.1402
# Epoch: 033/040
# Train ACC: 95.83 | Validation ACC: 73.40
# Time elapsed: 11.32 min
# Epoch: 034/040 | Batch 000/188 | Cost: 0.1753
# Epoch: 034/040 | Batch 150/188 | Cost: 0.1123
# Epoch: 034/040
# Train ACC: 94.36 | Validation ACC: 71.75
# Time elapsed: 11.65 min
# Epoch: 035/040 | Batch 000/188 | Cost: 0.1234
# Epoch: 035/040 | Batch 150/188 | Cost: 0.1605
# Epoch: 035/040
# Train ACC: 95.83 | Validation ACC: 72.55
# Time elapsed: 11.98 min
# Epoch: 036/040 | Batch 000/188 | Cost: 0.1747
# Epoch: 036/040 | Batch 150/188 | Cost: 0.1461
# Epoch: 036/040
# Train ACC: 96.04 | Validation ACC: 72.80
# Time elapsed: 12.32 min
# Epoch: 037/040 | Batch 000/188 | Cost: 0.1510
# Epoch: 037/040 | Batch 150/188 | Cost: 0.1020
# Epoch: 037/040
# Train ACC: 95.98 | Validation ACC: 71.45
# Time elapsed: 12.65 min
# Epoch: 038/040 | Batch 000/188 | Cost: 0.1764
# Epoch: 038/040 | Batch 150/188 | Cost: 0.1632
# Epoch: 038/040
# Train ACC: 96.54 | Validation ACC: 72.20
# Time elapsed: 12.98 min
# Epoch: 039/040 | Batch 000/188 | Cost: 0.1404
# Epoch: 039/040 | Batch 150/188 | Cost: 0.2018
# Epoch: 039/040
# Train ACC: 95.75 | Validation ACC: 73.20
# Time elapsed: 13.32 min
# Epoch: 040/040 | Batch 000/188 | Cost: 0.0842
# Epoch: 040/040 | Batch 150/188 | Cost: 0.1568
# Epoch: 040/040
# Train ACC: 96.84 | Validation ACC: 73.80
# Time elapsed: 13.65 min
# Total Training Time: 13.65 min

# %% [markdown]
# # 5.评估

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(cost_list, label='Minibatch cost')
plt.plot(np.convolve(cost_list, 
                     np.ones(200,)/200, mode='valid'), 
         label='Running average')

plt.ylabel('Cross Entropy')
plt.xlabel('Iteration')
plt.legend()

# %%
plt.plot(np.arange(1, NUM_EPOCHS+1), train_acc_list, label='Training')
plt.plot(np.arange(1, NUM_EPOCHS+1), valid_acc_list, label='Validation')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# %%
with torch.set_grad_enabled(False):
    test_acc = compute_acc(model=model,
                           data_loader=test_loader,
                           device=DEVICE)
    
    valid_acc = compute_acc(model=model,
                            data_loader=valid_loader,
                            device=DEVICE)
    

print(f'Validation ACC: {valid_acc:.2f}%')
print(f'Test ACC: {test_acc:.2f}%')
# Out:
# Validation ACC: 73.00%
# Test ACC: 73.31%
